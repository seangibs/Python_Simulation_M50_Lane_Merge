# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Utilities" data-toc-modified-id="Utilities-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Utilities</a></span><ul class="toc-item"><li><span><a href="#Bell-Curve-Random-Generator" data-toc-modified-id="Bell-Curve-Random-Generator-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Bell Curve Random Generator</a></span></li><li><span><a href="#Free-Speed-Generator" data-toc-modified-id="Free-Speed-Generator-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Free Speed Generator</a></span></li></ul></li><li><span><a href="#Entities" data-toc-modified-id="Entities-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Entities</a></span><ul class="toc-item"><li><span><a href="#Lanes" data-toc-modified-id="Lanes-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Lanes</a></span></li><li><span><a href="#Vehicles" data-toc-modified-id="Vehicles-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Vehicles</a></span><ul class="toc-item"><li><span><a href="#Property-Surround" data-toc-modified-id="Property-Surround-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Property Surround</a></span></li></ul></li></ul></li><li><span><a href="#Recorder" data-toc-modified-id="Recorder-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Recorder</a></span><ul class="toc-item"><li><span><a href="#Load-Data" data-toc-modified-id="Load-Data-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Load Data</a></span></li><li><span><a href="#Comparing-Data" data-toc-modified-id="Comparing-Data-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Comparing Data</a></span></li></ul></li><li><span><a href="#Testing-New-Functionality" data-toc-modified-id="Testing-New-Functionality-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Testing New Functionality</a></span><ul class="toc-item"><li><span><a href="#Traffic-Flow-in-veh/h" data-toc-modified-id="Traffic-Flow-in-veh/h-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Traffic Flow in veh/h</a></span></li><li><span><a href="#Traffic-Density-im-veh/km" data-toc-modified-id="Traffic-Density-im-veh/km-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Traffic Density im veh/km</a></span></li><li><span><a href="#Average-Travel-Times-in-s" data-toc-modified-id="Average-Travel-Times-in-s-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Average Travel Times in s</a></span></li><li><span><a href="#Average-Speed-in-km/h" data-toc-modified-id="Average-Speed-in-km/h-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Average Speed in km/h</a></span></li><li><span><a href="#Fundamental-Law" data-toc-modified-id="Fundamental-Law-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Fundamental Law</a></span></li></ul></li><li><span><a href="#Simulation" data-toc-modified-id="Simulation-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Simulation</a></span></li><li><span><a href="#Verification" data-toc-modified-id="Verification-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Verification</a></span><ul class="toc-item"><li><span><a href="#Construction-of-Motorway-Segments" data-toc-modified-id="Construction-of-Motorway-Segments-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Construction of Motorway Segments</a></span><ul class="toc-item"><li><span><a href="#Testing-the-Construction-of-Single-Lane-Motorway" data-toc-modified-id="Testing-the-Construction-of-Single-Lane-Motorway-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Testing the Construction of Single Lane Motorway</a></span></li><li><span><a href="#Testing-the-Construction-of-Multilane-Motorway-Segments" data-toc-modified-id="Testing-the-Construction-of-Multilane-Motorway-Segments-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Testing the Construction of Multilane Motorway Segments</a></span></li><li><span><a href="#Construction-of-Multilane-Motorway-Segments-with-Speed-Limit" data-toc-modified-id="Construction-of-Multilane-Motorway-Segments-with-Speed-Limit-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Construction of Multilane Motorway Segments with Speed Limit</a></span></li><li><span><a href="#Constructing-a-Motorway-On-Ramp" data-toc-modified-id="Constructing-a-Motorway-On-Ramp-6.1.4"><span class="toc-item-num">6.1.4&nbsp;&nbsp;</span>Constructing a Motorway On-Ramp</a></span></li></ul></li><li><span><a href="#Controlled-Lane-Change" data-toc-modified-id="Controlled-Lane-Change-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Controlled Lane Change</a></span></li><li><span><a href="#Automatic-Overtaking" data-toc-modified-id="Automatic-Overtaking-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Automatic Overtaking</a></span></li><li><span><a href="#One-Vehicle-Fixed-Speed-Profile" data-toc-modified-id="One-Vehicle-Fixed-Speed-Profile-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>One Vehicle Fixed Speed Profile</a></span><ul class="toc-item"><li><span><a href="#Accelleration-Only-(Short-Distance)" data-toc-modified-id="Accelleration-Only-(Short-Distance)-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Accelleration Only (Short Distance)</a></span></li><li><span><a href="#Accelleration-and-Cruising-(Longer-Distance)" data-toc-modified-id="Accelleration-and-Cruising-(Longer-Distance)-6.4.2"><span class="toc-item-num">6.4.2&nbsp;&nbsp;</span>Accelleration and Cruising (Longer Distance)</a></span></li><li><span><a href="#Accelleration-and-Decelleration" data-toc-modified-id="Accelleration-and-Decelleration-6.4.3"><span class="toc-item-num">6.4.3&nbsp;&nbsp;</span>Accelleration and Decelleration</a></span></li></ul></li><li><span><a href="#Multiple-Vehicles-with-Fixed-Speed-Profile" data-toc-modified-id="Multiple-Vehicles-with-Fixed-Speed-Profile-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Multiple Vehicles with Fixed Speed Profile</a></span></li><li><span><a href="#Testing-Vehicles-with-Random-Speed-Profile" data-toc-modified-id="Testing-Vehicles-with-Random-Speed-Profile-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Testing Vehicles with Random Speed Profile</a></span><ul class="toc-item"><li><span><a href="#A-Single-Vehicle-of-Varying-Speed" data-toc-modified-id="A-Single-Vehicle-of-Varying-Speed-6.6.1"><span class="toc-item-num">6.6.1&nbsp;&nbsp;</span>A Single Vehicle of Varying Speed</a></span></li><li><span><a href="#Multiple-Vehicles-with-Varying-Speeds" data-toc-modified-id="Multiple-Vehicles-with-Varying-Speeds-6.6.2"><span class="toc-item-num">6.6.2&nbsp;&nbsp;</span>Multiple Vehicles with Varying Speeds</a></span></li></ul></li><li><span><a href="#Multiple-Vehicles-with-Fixed-Speed-Profile-(Emergency-Braking)" data-toc-modified-id="Multiple-Vehicles-with-Fixed-Speed-Profile-(Emergency-Braking)-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Multiple Vehicles with Fixed Speed Profile (Emergency Braking)</a></span><ul class="toc-item"><li><span><a href="#Two-Vehicles-on-a-Single-Lane" data-toc-modified-id="Two-Vehicles-on-a-Single-Lane-6.7.1"><span class="toc-item-num">6.7.1&nbsp;&nbsp;</span>Two Vehicles on a Single Lane</a></span></li><li><span><a href="#Same-Scenario-on-Two-Lanes" data-toc-modified-id="Same-Scenario-on-Two-Lanes-6.7.2"><span class="toc-item-num">6.7.2&nbsp;&nbsp;</span>Same Scenario on Two Lanes</a></span></li><li><span><a href="#Multiple-Vehicles-on-a-Single-Lane" data-toc-modified-id="Multiple-Vehicles-on-a-Single-Lane-6.7.3"><span class="toc-item-num">6.7.3&nbsp;&nbsp;</span>Multiple Vehicles on a Single Lane</a></span></li><li><span><a href="#Same-Scenario-on-Two-Lanes" data-toc-modified-id="Same-Scenario-on-Two-Lanes-6.7.4"><span class="toc-item-num">6.7.4&nbsp;&nbsp;</span>Same Scenario on Two Lanes</a></span></li><li><span><a href="#A-Larger-Number-of-Vehicles-on-a-Single-Lane" data-toc-modified-id="A-Larger-Number-of-Vehicles-on-a-Single-Lane-6.7.5"><span class="toc-item-num">6.7.5&nbsp;&nbsp;</span>A Larger Number of Vehicles on a Single Lane</a></span></li><li><span><a href="#Same-Scenario-again-on-two-Lanes" data-toc-modified-id="Same-Scenario-again-on-two-Lanes-6.7.6"><span class="toc-item-num">6.7.6&nbsp;&nbsp;</span>Same Scenario again on two Lanes</a></span></li></ul></li><li><span><a href="#Multiple-Vehicles-with-Fixed-Speed-Profile-(Crash-Scenario)" data-toc-modified-id="Multiple-Vehicles-with-Fixed-Speed-Profile-(Crash-Scenario)-6.8"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>Multiple Vehicles with Fixed Speed Profile (Crash Scenario)</a></span><ul class="toc-item"><li><span><a href="#Two-Vehicles-with-Not-Enough-Distance-in-between" data-toc-modified-id="Two-Vehicles-with-Not-Enough-Distance-in-between-6.8.1"><span class="toc-item-num">6.8.1&nbsp;&nbsp;</span>Two Vehicles with Not Enough Distance in between</a></span></li><li><span><a href="#Multiple-Vehicles-with-Not-Enough-Distance-in-between¶" data-toc-modified-id="Multiple-Vehicles-with-Not-Enough-Distance-in-between¶-6.8.2"><span class="toc-item-num">6.8.2&nbsp;&nbsp;</span>Multiple Vehicles with Not Enough Distance in between¶</a></span></li></ul></li><li><span><a href="#Row-of-Vehicles-with-Varying-Speed" data-toc-modified-id="Row-of-Vehicles-with-Varying-Speed-6.9"><span class="toc-item-num">6.9&nbsp;&nbsp;</span>Row of Vehicles with Varying Speed</a></span></li><li><span><a href="#Speed-Limit" data-toc-modified-id="Speed-Limit-6.10"><span class="toc-item-num">6.10&nbsp;&nbsp;</span>Speed Limit</a></span></li><li><span><a href="#Motorway-On-Ramp" data-toc-modified-id="Motorway-On-Ramp-6.11"><span class="toc-item-num">6.11&nbsp;&nbsp;</span>Motorway On-Ramp</a></span><ul class="toc-item"><li><span><a href="#A-Single-Vehicle-Merging-onto-an-Empty-Motorway" data-toc-modified-id="A-Single-Vehicle-Merging-onto-an-Empty-Motorway-6.11.1"><span class="toc-item-num">6.11.1&nbsp;&nbsp;</span>A Single Vehicle Merging onto an Empty Motorway</a></span></li><li><span><a href="#Multiple-Vehicles-Merging-onto-an-Empty-Motorway" data-toc-modified-id="Multiple-Vehicles-Merging-onto-an-Empty-Motorway-6.11.2"><span class="toc-item-num">6.11.2&nbsp;&nbsp;</span>Multiple Vehicles Merging onto an Empty Motorway</a></span></li><li><span><a href="#A-Single-Vehicle-Merging-onto-a-busy-Motorway" data-toc-modified-id="A-Single-Vehicle-Merging-onto-a-busy-Motorway-6.11.3"><span class="toc-item-num">6.11.3&nbsp;&nbsp;</span>A Single Vehicle Merging onto a busy Motorway</a></span></li><li><span><a href="#Multiple-Vehicles-Merging-onto-a-very-busy-Motorway" data-toc-modified-id="Multiple-Vehicles-Merging-onto-a-very-busy-Motorway-6.11.4"><span class="toc-item-num">6.11.4&nbsp;&nbsp;</span>Multiple Vehicles Merging onto a very busy Motorway</a></span></li></ul></li><li><span><a href="#Row-of-Vehicles-with-Varying-Speed-and-Interarrival-Times" data-toc-modified-id="Row-of-Vehicles-with-Varying-Speed-and-Interarrival-Times-6.12"><span class="toc-item-num">6.12&nbsp;&nbsp;</span>Row of Vehicles with Varying Speed and Interarrival Times</a></span></li><li><span><a href="#Row-of-Vehicles-with-Varying-Max-Speed,-Speed-and-Interarrival-Times" data-toc-modified-id="Row-of-Vehicles-with-Varying-Max-Speed,-Speed-and-Interarrival-Times-6.13"><span class="toc-item-num">6.13&nbsp;&nbsp;</span>Row of Vehicles with Varying Max Speed, Speed and Interarrival Times</a></span></li></ul></li></ul></div>

# %% [markdown]
# <div style="background-color:rgba(0,0,255,0.4); padding:10px 10px;">
# This version adds statistic support.
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import math
import numpy as np
import random

import simpy

# %% [markdown]
# # Utilities

# %%
def isZero(x, ε = 0.00001):
    return abs(x)<ε

# %% [markdown]
# ## Bell Curve Random Generator

# %%
gen_x_tab = None
gen_y_tab = None

def pdfv(x, mean=0, sd=None, delta=None):
    
    if sd is None and delta is None:
        sd = 1
    elif sd is None and delta is not None:
        sd = delta/math.sqrt(6)*0.9275
    
    τ = math.sqrt(6)
    x = (x-mean)/sd*0.9275
    return np.where(abs(x)<τ, 5/(8*τ*sd)*(1-x**2/2+x**4/24+1/2)*0.9275, 0)

def rv(mean=0, sd=None, delta=None, alternating=None, rounding=None):
    
    if sd is None and delta is None:
        sd = 1
    elif sd is None and delta is not None:
        sd = delta/math.sqrt(6)*0.9275

    global gen_count, gen_x_tab, gen_y_tab
    
    if gen_x_tab is None:
        
        # initialise global variables 
        gen_x_tab = list(np.linspace(-math.sqrt(6), -1.51, 500)) + \
                    list(np.linspace(-1.5, 0, 151)) 

        τ = math.sqrt(6)
        
        def cdf(x):
            return 5/(8*τ)*(x**5/120-x**3/6+x*3/2)+5/(8*τ)*(τ**5/120-τ**3/6+τ*3/2)
        
        gen_y_tab = [ cdf(x) for x in gen_x_tab ]
        
    y, sign = random.random(), 1
    if y>0.5:
        y, sign = 1-y, -1
    if alternating is not None:
        sign = 1 if alternating%2==0 else -1

    for i in range(1, len(gen_x_tab)):
        if y < gen_y_tab[i]:
            x0 = gen_x_tab[i]
            y0 = gen_y_tab[i]
            x1 = gen_x_tab[i-1]
            y1 = gen_y_tab[i-1]
            x = mean+sign*((x0+(y-y0)*(x1-x0)/(y1-y0))*sd/0.9275)
            if type(rounding) is int and rounding>0:
                return round(x, rounding)
            else:
                return x

# %%
rv80 = [ rv(mean=80, delta=10) for i in range(100000) ]
_ = plt.hist(rv80, bins=100, density=True)

X = np.linspace(70, 90, 100)
Y = pdfv(X, mean=80, delta=10)
_ = plt.plot(X, Y, color='red')

# %% [markdown]
# ## Free Speed Generator

# %%
free_speed_bins = [ 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160]
free_speed_quantiles = np.cumsum([0, 0.006, 0.014, 0.052, 0.148, 0.27, 0.309, 0.143, 0.048, 0.01])

def free_speed_distribution():
    u = random.random() # generates uniformly distributed random number between 0 and 1
    for i in range(len(free_speed_quantiles)):
        if u<free_speed_quantiles[i+1]:
            p = (u-free_speed_quantiles[i])/(free_speed_quantiles[i+1]-free_speed_quantiles[i])
            return free_speed_bins[i]*p+free_speed_bins[i+1]*(1-p)
        
free_speed_data = [ free_speed_distribution() for i in range(1200)]
free_speed_kernel = stats.gaussian_kde(free_speed_data)

free_speeds = np.arange(30, 191)
free_speed_cdf = [ free_speed_kernel.integrate_box_1d(30, i) for i in free_speeds ]

def random_free_speed():
    u = random.random() # generates uniformly distributed random number between 0 and 1
    for i in range(len(free_speeds)):
        if u<free_speed_cdf[i+1]:
            p = (u-free_speed_cdf[i])/(free_speed_cdf[i+1]-free_speed_cdf[i])
            return free_speeds[i]*p+free_speeds[i+1]*(1-p)

# %%
speeds = [ random_free_speed() for i in range(100000) ]
_ = plt.hist(speeds, bins=1000, density=True)
x = np.arange(60, 160, 1)
y = free_speed_kernel(x)
_ = plt.plot(x, y, color='red')

# %% [markdown]
# # Entities

# %% [markdown]
# ## Lanes

# %% [markdown]
# [TOC](#Table-of-Contents) [Up](#Entities) [Next](#Vehicles)

# %% [markdown]
# The class `Lane` describes a segment of a lane. It has the width allowing only one vehicle at a point in the lane. i.e. there is no overtaking. Lane segments will be concatenated to form long stretches of road, and will be attached sidewise to each other to form multi lane infrastructure.
#
# Lanes have a state consisting of the vehicles that are at a particular point in time on the lane segment.

# %%
def normaliseDirection(d):
    d = d.lower()
    if d=='r' or d=='fast':
        return 'fast'
    elif d=='l' or d=='slow':
        return 'slow'
    else:
        return None

# %%
LANE_ID = 0

class Lane:
    
    def __init__(self, rec, length, speedLimit=None, merge=None):
        
        global LANE_ID
        self.id = LANE_ID
        LANE_ID += 1
      
        self.rec = rec
        self.x0 = 0
        self.length = length
        
        # speed limit on this lane segment in km/h
        self.speedLimit = speedLimit 
        
        # indicates that at the end of the lance traffic has to merge to the left or right
        self.merge = merge 
        
        self.vehicles = []
        
        self.next = None
        self.prev = None
                
        # lane attached to the left/right
        self.left = None
        self.right = None
        
        rec.recordLane(self)
      
    # defines generic str() method for Lanes
    def __str__(self):
        l = " L:--" if self.left is None else f" L:{self.left.id:0>2d}"
        r = " R:--" if self.right is None else f" R:{self.right.id:0>2d}"
        s = "" if self.speedLimit is None else f" speedLimit:{self.speedLimit:d}km/h"
        return f"[{self.id:0>2d} x={self.x0:3.1f}m l={self.length:3.1f}m"+l+r+s+"]" + \
                    ("\\" if self.merge=='R' else "") + \
                    ("/" if self.merge=='L' else "") + \
                    ("-" + str(self.next) if self.next is not None else "")
    
    def getLane(self, direction):
        if direction=='slow':
            return self.left
        elif direction=='fast':
            return self.right
        else:
            return None

    ## additional code    
    # adding parallel lane on right side
    def attachRight(self, lane):
        self.right = lane
        lane.left = self
        lane.x0 = self.x0
        lane.speedLimit = self.speedLimit
 
    ## additional code 
    # adding parallel lane on right side
    def attachLeft(self, lane):
        self.left = lane
        lane.right = self
        lane.x0 = self.x0
        lane.speedLimit = self.speedLimit
     
    ## additional code 
    # constructs a number of lane segments of the same length
    # and attaches them to the right
    def widenRight(self):
        lane = self
        newLane = Lane(self.rec, lane.length)
        lane.attachRight(newLane)
        while lane.next is not None:
            lane = lane.next
            newLane = Lane(self.rec, lane.length)
            lane.attachRight(newLane)
            newLane.prev = lane.prev.right
            newLane.prev.next = newLane
        return self.right
            
    ## additional code 
    # constructs a number of lane segments of the same length
    # and attaches them to the right
    def widenLeft(self):
        lane = self
        newLane = Lane(self.rec, lane.length)
        lane.attachLeft(newLane)
        while lane.next is not None:
            lane = lane.next
            newLane = Lane(self.rec, lane.length)
            lane.attachLeft(newLane)
            newLane.prev = lane.prev.left
            newLane.prev.next = newLane
        return self.left
            
    # defines concatenation of lanes
    def extend(self, lane):
        l = self
        while l.next is not None:
            l = l.next
        l.next = lane
        lane.x0 = l.x0+l.length
        lane.prev = l
        return self
        
    def totalLength(self):
        total = self.length
        l = self
        while l.next is not None:
            l = l.next
            total += l.length
        return total
    
    def between(self, posBack, posFront):
        # make sure that the position of all cars is accurate 
        # at this point in time
        for v in self.vehicles:
            v.updateOnly()
                # normally the list should be sorted, but just in case
        self.vehicles.sort(key=lambda v: v.pos)
        res = []
        for v in self.vehicles:
            if posBack < v.pos and v.pos-v.length < posFront:
                res.append(v)
        # if the required distance reaches over the end of the lane segment
        if posFront > self.length and self.next is not None:
            return res + self.next.between(0, posFront-self.length)
        elif posBack < 0 and self.prev is not None:
            return self.prev.between(self.prev.length+posBack, self.prev.length) + res
        else:
            return res
        
    def inFront(self, pos, far):
        # make sure that the position of all cars is accurate 
        # at this point in time
        for v in self.vehicles:
            v.updateOnly()
        # normally the list should be sorted, but just in case
        self.vehicles.sort(key=lambda v: v.pos)
        for v in self.vehicles:
            if v.pos > pos:
                return v if v.pos-pos<far else None
        # there is none in front in this lance
        # if the free lane in front is long enough or there is no next lane
        if self.length-pos>far or self.next is None:
            return None
        else:
            return self.next.inFront(0, far-(self.length-pos))

    def behind(self, pos, far):
        # make sure that the position of all cars is accurate 
        # at this point in time
        for v in self.vehicles:
            v.updateOnly()
        # This time we sort in reverse order
        self.vehicles.sort(key=lambda v: v.pos, reverse=True)
        for v in self.vehicles:
            if v.pos < pos:
                return v if pos-v.pos<far else None
        # there is none behind in this lance
        # if the free lane in behind is long enough or there is no previous lane
        if pos>far or self.prev is None:
            return None
        else:
            return self.prev.behind(self.prev.length, far-pos)
        
    def enter(self, vehicle, pos=0, laneChange=False):
        self.vehicles.insert(0, vehicle)
        vehicle.pos = pos
        vehicle.lane = self
        vehicle.rec.record(vehicle, event="enter lane"+(f" {self.id:d}" if laneChange else ""))

    def leave(self, vehicle, laneChange=False):
        vehicle.rec.record(vehicle, event="leave lane"+(f" {self.id:d}" if laneChange else ""))
        vehicle.lane = None
        self.vehicles.remove(vehicle)
    
    def getEnd(self):
        return self.x0 + self.length

# %% [markdown]
# ## Vehicles

# %% [markdown]
# [TOC](#Table-of-Contents) [Up](#Entities) [Prev](#Lanes) [Next](#Recorder)

# %% [markdown]
# The class Vehicle is introduced as clone of the class P.

# %%
def isRunning(p):
    return p is not None and p.running

def isCrashed(p):
    return p is not None and p.crashed

# %%
VEHICLE_ID = 0

class Vehicle:
    def __init__(self, rec, 
                 startingLane=None, startingPos=0,
                 t0=0, x0=0, dx0=0, ddx0=0, dddx0=0, 
                 vmax=None, vmax_var=None,
                 t=[], v=[]):
        
        global VEHICLE_ID
        self.id = VEHICLE_ID
        VEHICLE_ID += 1
        
        self.a_brake = -4.0 # [m/s²]   Tesla: -8.0 # [m/s²]
        self.a_coast = -0.6 # [m/s²]   Tesla: -1.8 # [m/s²]   
        self.a_max =    2.5 # [m/s²]   Tesla:  4.6 # [m/s²] 
                            # Note: 2.5m/s² corresponds to 0-100km/h om 11s
        self.length = 4 # [m]  Length of the vehicle 
        
        self.absolute_speed_time_tolerance = 2 # [s]
        self.relative_speed_time_tolerance = 5 # [s]
        self.far_away_in_front = 200 # [m]
        self.far_away_in_back = 80 # [m]
        self.min_action_time = 0.5 # [s]  
        
        self.lane_change_time = 3 # [s] 
        self.min_speed_diff = 2 # [m/s]
        
        ## if not None the preferred max free velocity
        self.vmax = vmax
        self.vmax_variation = vmax_var if vmax_var is not None else 0.05
        self.timing = 100 # [s]
        self.timing_variation = 0.30 
        
        self.env = rec.env
        self.rec = rec
            
        self.startingLane = startingLane
        self.startingPos = startingPos
        self.lane = None
        self.pos = 0
        
        # speedLimit once recognised
        self.speedLimit = None
        
        ## second lane reference during changing of lanes
        self.oldLane = None
        
        self.alternator = 0
            
        self.t0 = t0
        self.x0 = x0    # [m] the reference point is on the front of the vehicle
                        # the body of the vehicle of the given length is behind.
        self.dx0 = dx0
        self.ddx0 = ddx0
        self.dddx0 = dddx0

        self.t_target = t
        self.v_target = v
        # while there is an adjustment of velocity in progress
        # the current_target is set
        self.current_target = None

        # trace flags
        self.traceAdjustVelocity = False
        self.traceInterrupt = False
        self.traceBraking = False
        self.traceCrash = False
        self.traceSurround = False
        self.traceOvertaking = False
 
        # start process
        self.running = False
        self.crashed = False
                
        # Flags used for temporarily exclusive behaviour
        self.laneChangeControl = False 
                # This flag is used to block automatic overtaking
                # while processing explicit lane change control
        self.braking = False
                # This flag is used to prevent interrupting braking for braking
        self.changingLane = False
                # This flag is used to prevent interrupting lanechanging
        
        self.processRef = None
        self.env.process(self.process())
    
    def trace(self, message):
        print(f"t={self.t0:7,.1f}s x={self.x0:7,.1f}m v{self.id:d}", message)
        
    def isNotFasterThan(self, other):
        return True if other is None else self.dx0 <= other.dx0
    
    def isNotSlowerThan(self, other):
        return True if other is None else other.dx0 <= self.dx0
    
    ## adapted to handle lane information
    def updateOnly(self):
        t = self.env.now
        if t < self.t0 or not self.running:
            return False
        if t > self.t0:
            dt = t - self.t0
            ddx = self.ddx0 + self.dddx0*dt
            dx = self.dx0 + self.ddx0*dt + self.dddx0*dt*dt/2
            Δx = self.dx0*dt + self.ddx0*dt*dt/2 + self.dddx0*dt*dt*dt/6
            x = round(self.x0 + Δx, 2)
            self.t0, self.x0, self.dx0, self.ddx0 = t, x, dx, ddx
            
            ## begin additional code
            self.pos = round(self.pos+Δx, 2)
            # update lane information if necessary
            if self.pos >= self.lane.length:
                nextPos = self.pos - self.lane.length
                nextLane = self.lane.next
                self.lane.leave(self)
                if nextLane is None:
                    self.oldLane = None
                    self.rec.record(self, event='end')
                    self.running = False
                    return False
                else:
                    nextLane.enter(self, pos=nextPos)
            ## end additional code
            
        return True
        
    ## minor change only
    def update(self):
        
        self.surround = Surround(self)
        
        ## instead of direct link, call method
        inFront = self.surround.front
        
        # if there is a running or crashed vehicle in front and
        # we have crashed into the rear end of that vehicle
        if inFront is not None and inFront.x0-inFront.length < self.x0:
            self.crash(inFront)

        # if the speedLimit changes...
        elif self.speedLimit != self.lane.speedLimit:
            self.speedLimit = self.lane.speedLimit
            if self.speedLimit is None:
                # end of speed limit, return to default behaviour
                if self.vmax is not None and self.vmax>self.dx0:
                    Δt = max(self.min_action_time, (self.vmax-self.dx0)/self.a_max)
                    self.setTarget(Δt, self.vmax)
            else:
                vmax = self.speedLimit/3.6
                vmax = rv(mean=vmax, delta=self.vmax_variation*vmax)
                if vmax<self.dx0:
                    # when the new speedLimit is lower than current speed, coast down
                    Δt = max(self.min_action_time, (self.dx0-vmax)/self.a_coast)
                    self.setTarget(Δt, vmax)
                else:
                    # when the new speedLimit is higher than current speed, accelerate at half max a_max
                    Δt = max(self.min_action_time, 2*(vmax-self.dx0)/self.a_max)
                    self.setTarget(Δt, vmax)
                
        # if at the end of the lane merging is required      
        elif self.lane.merge is not None and \
                not self.braking and not self.laneChangeControl and not self.changingLane:
            if self.lane.merge == 'R':
                # if merge is clear, merge
                if self.surround.rightLane is not None and \
                        self.surround.right is None and \
                        self.isNotFasterThan(self.surround.rightFront) and \
                        self.isNotSlowerThan(self.surround.rightBack):
                    self.setTarget(self.lane_change_time, 'fast')
                # if merge is clear, but we are faster than the front right car, slow down 
                elif self.surround.rightLane is not None and \
                        self.surround.right is None and \
                        self.isNotSlowerThan(self.surround.rightBack) and \
                        not self.isNotFasterThan(self.surround.rightFront):
                    self.setTarget(self.min_action_time, self.dx0*.9)
                # if merge is clear, but we are slower than back right car and we have room, speed up
                elif self.surround.rightLane is not None and \
                        self.surround.right is None and \
                        not self.isNotSlowerThan(self.surround.rightBack) and \
                        self.isNotFasterThan(self.surround.rightFront) and \
                        self.lane.getEnd() - self.x0 > -5*(self.dx0**2/(2*self.a_brake)):
                    self.setTarget(self.min_action_time, self.dx0*1.1)
                # if we are very close to the end of the merge lane, stop
                elif (self.lane.getEnd() - self.x0) < -1.1*(self.dx0**2/(2*self.a_brake)):
                    self.setTarget(self.min_action_time, 0)
                # if we are moderately close to end of merge lane, slow down 20 percent
                elif (self.lane.getEnd() - self.x0) < -2*(self.dx0**2/(2*self.a_brake)):
                    self.setTarget(self.min_action_time, self.dx0*.8)
                # if we are kinda close to the end of the merge lane, slow down 10 percent
                elif (self.lane.getEnd() - self.x0) < -4*(self.dx0**2/(2*self.a_brake)):
                    self.setTarget(self.min_action_time, self.dx0*.9)

            elif self.lane.merge == 'L':
                # if merge is clear, merge
                if self.surround.leftLane is not None and \
                        self.surround.left is None and \
                        self.isNotFasterThan(self.surround.leftFront) and \
                        self.isNotSlowerThan(self.surround.leftBack):
                    self.setTarget(self.lane_change_time, 'slow') 
                # if merge is clear, but we are faster than the front left car, slow down
                elif self.surround.leftLane is not None and \
                        self.surround.left is None and \
                        self.isNotSlowerThan(self.surround.leftBack) and \
                        not self.isNotFasterThan(self.surround.leftFront):
                    self.setTarget(self.min_action_time, self.dx0*.9)
                # if merge is clear, but we are slower than back left car and we have room, speed up
                elif self.surround.leftLane is not None and \
                        self.surround.left is None and \
                        not self.isNotSlowerThan(self.surround.leftBack) and \
                        self.isNotFasterThan(self.surround.leftFront) and \
                        self.lane.getEnd() - self.x0 > -5*(self.dx0**2/(2*self.a_brake)):
                    self.setTarget(self.min_action_time, self.dx0*1.1)
                # if we are very close to the end of the merge lane, stop
                elif (self.lane.getEnd() - self.x0) < -1.1*(self.dx0**2/(2*self.a_brake)):
                    self.setTarget(self.min_action_time, 0)
                # if we are moderately close to end of merge lane, slow down 20 percent
                elif (self.lane.getEnd() - self.x0) < -2*(self.dx0**2/(2*self.a_brake)):
                    self.setTarget(self.min_action_time, self.dx0*.8)
                # if we are kinda close to the end of the merge lane, slow down 10 percent
                elif (self.lane.getEnd() - self.x0) < -4*(self.dx0**2/(2*self.a_brake)):
                    self.setTarget(self.min_action_time, self.dx0*.9)
        
        # start overtaking maneuver by changing into fast lane
        elif inFront is not None and \
                not self.braking and not self.laneChangeControl and not self.changingLane and \
                self.dx0 > inFront.dx0 + self.min_speed_diff and \
                self.x0 + (self.lane_change_time+self.absolute_speed_time_tolerance)*self.dx0 > inFront.x0-inFront.length and \
                self.surround.rightLane is not None and \
                self.surround.right is None and \
                self.isNotFasterThan(self.surround.rightFront) and \
                self.isNotSlowerThan(self.surround.rightBack):
            self.setTarget(self.lane_change_time, 'fast')

        # if there is a vehicle in front 
        # which drives slower and
        # the distance to that vehicle in front is at current speed
        # less than the critical time tolerance of this driver
        elif inFront is not None and \
                not self.braking and not self.laneChangeControl and not self.changingLane and \
                self.dx0 > inFront.dx0 and \
                self.x0 + self.absolute_speed_time_tolerance*self.dx0 > inFront.x0:
            # note that self.a_coast is a negative acceleration
            Δt = max(self.min_action_time, (inFront.dx0-self.dx0)/self.a_coast)
            if self.current_target is None or \
                    not isZero(self.current_target-inFront.dx0):
                self.setTarget(Δt, inFront.dx0)

        # end overtaking by returning to slow lane
        elif self.surround.leftLane is not None and \
                not self.braking and not self.laneChangeControl and not self.changingLane and \
                self.surround.leftLane.totalLength()-self.pos>100 and \
                self.surround.left is None and \
                self.isNotSlowerThan(self.surround.leftBack) and \
                self.surround.leftFront is None:
            self.setTarget(self.lane_change_time, 'slow')
     
    ## code remains unchanged
    def setTarget(self, t, v):
        self.t_target = [ t ] + self.t_target
        self.v_target = [ v ] + self.v_target
        self.interruptProcess()
      
    ## minor change only
    def process(self):

        # delay start to the given time t-
        if self.t0>self.env.now:
            yield self.env.timeout(self.t0-self.env.now)
        self.t0 = self.env.now
        self.running = True
        self.rec.startRecording(self)
        
        ## begin additional code
        ## enter the first lane
        self.startingLane.enter(self)
        ## end additional code
        
        while self.updateOnly():

            ## instead of direct link, call method
            inFront = self.lane.inFront(self.pos, self.far_away_in_front) \
                        if self.lane is not None else None
                
            # if the car in front is slower and we are a bit too near on its heals...
            if inFront is not None and inFront.dx0 < self.dx0 and \
                    inFront.x0-inFront.length < \
                        self.x0 + self.relative_speed_time_tolerance*(self.dx0-inFront.dx0):
                yield from self.emergencyBraking(inFront.dx0)
                if not isZero(self.dx0-inFront.dx0):
                    # after emergency breaking adjust to the speed of the car in front...
                    Δt = 1
                    self.setTarget(Δt, inFront.dx0)
                continue 
                    
            if len(self.t_target)>0:
                
                t_target = self.t_target[0]
                v_target = self.v_target[0]
                self.t_target = self.t_target[1:]
                self.v_target = self.v_target[1:]
                
                if type(v_target) is str:
                    
                    # explicit overtake commands temporarily
                    # disable overtaking
                    if v_target=='R':
                        self.laneChangeControl = True
                    elif v_target=='L':
                        self.laneChangeControl = False
                        
                    direction = normaliseDirection(v_target)
                    if self.lane.getLane(direction) is not None:
                        yield from self.changeLane(inFront, direction, t_target)
                
                ## the rest is what was there before
                else:
                    v0 = self.dx0
                    v1 = v_target
                    Δt = t_target
                    if isZero(v1-v0):
                        yield from self.continueAtSameSpeed(Δt)
                    else:
                        yield from self.adjustVelocity(v1-v0, Δt)
                    
            ## additional code
            elif self.vmax is not None:
                
                # if the explicit control strategy is exhausted and
                # a target maximum speed is set the vehicle will follow
                # a random speed around the target maximum speed

                ## additional code
                vmax = self.vmax
                if self.speedLimit is not None:
                    vmax = self.speedLimit/3.6
                    vmax = rv(mean=vmax, delta=self.vmax_variation*vmax)
                    
                # as long there is no vehicle in front or the vehicle in front
                # is far enough ahead
                if inFront is None or \
                    self.x0 + self.relative_speed_time_tolerance*(self.dx0-inFront.dx0) < inFront.x0:
                    v0 = self.dx0
                    self.alternator += 1
                    v1 = rv(mean=vmax, 
                            delta=self.vmax_variation*vmax, 
                            alternating=self.alternator,
                            rounding=2)
                    Δt = rv(mean=self.timing, 
                            delta=self.timing*self.timing_variation,
                            rounding=1)
                
                    yield from self.adjustVelocity(v1-v0, Δt)
                else:
                    yield from self.continueAtSameSpeed(10)
            else:
                yield from self.continueAtSameSpeed(10)
                
        self.rec.stopRecording(self)

    def crash(self, other):
        
        def recordCrash(v):
            v.rec.record(v, 'crash')
            v.running = False
            v.crashed = True
            # stop anything your are currently doing...
            v.interruptProcess()
            v.dx0 = 0
            v.ddx0 = 0
            v.dddx0 = 0
            
        if self.running:
            if self.traceCrash:
                self.trace(f"Crashed into v{other.id:d} at x={self.x0:7.1f}m")
            recordCrash(self)
            if other.running:
                recordCrash(other)
        
    def emergencyBraking(self, v):
        
        def emergencyBrakingProcess(v):
            
            if self.traceBraking:
                self.trace(f"Braking from v={self.dx0:4.1f}m/s to {v:4.1f}m/s")
           
            self.rec.record(self, 'brake')
            minΔt = 0.2
            self.dddx0 = (self.a_brake-self.ddx0)/minΔt      
            yield self.env.timeout(minΔt)
            
            self.updateOnly()
            self.dddx0=0
            self.ddx0=self.a_brake
            v = min(v, self.dx0-2)
                # the brake time estimate is for perfect timing for 
                # autonomous cars. For manual driving leave out the
                # -minΔt/2 or use a random element.
            Δt = max(0.5, (v-self.dx0)/self.ddx0 - minΔt/2)
            yield self.env.timeout(Δt)
                
            self.updateOnly()
            self.dddx0 = -self.ddx0/minΔt      
            yield self.env.timeout(minΔt)
      
            self.updateOnly()
            self.ddx0 = 0
            self.dddx0 = 0
            self.rec.record(self, 'brake end')
            
            if self.traceBraking:
                self.trace(f"Braking end  v={self.dx0:4.1f}m/s")

        ## The 'braking' bit prevents the interruption of an emergency breaking process 
        self.braking = True
        self.processRef = self.env.process(emergencyBrakingProcess(v))
        try:
            yield self.processRef
        except simpy.Interrupt:
            if self.traceInterrupt or self.traceBraking:
                self.trace(f"Braking interrupted at v={self.dx0:4,.1f}m/s")
            pass
        self.processRef = None
        self.braking = False
        
    def changeLane(self, inFront, direction, Δt):
     
        def changeLaneProcess(oldLane, newlane, Δt, trace=True):
            # self.updateOnly()
            if trace and self.traceOvertaking and inFront is not None and  direction=='fast':
                other = f"v{inFront.id:d} " if inFront is not None else ""
                self.trace(f"Overtaking {other:s} at x={self.x0:7,.1f}m")
                
            self.rec.record(self, 'change '+direction)
            self.oldLane = oldLane
            newLane.enter(self, pos=self.pos, laneChange=True) 
            self.ddx0 = 1
            self.dddx0 = 0
            yield self.env.timeout(Δt)
            
            self.updateOnly()
            if not self.running:
                return
            currentLane = self.lane
            self.oldLane.leave(self, laneChange=True)
            self.lane = currentLane
            self.oldLane = None
            self.ddx0 = 0
            self.dddx0 = 0
            self.rec.record(self, 'done change '+direction)
            
            if trace and self.traceOvertaking and direction=='slow':
                self.trace(f"Overtaking done return to slow lane at x={self.x0:7,.1f}m")
            # self.updateOnly()
        
        ## keep record of current lane, as in case of aborting
        ## the lane change 
        ## when interrupted go back into original lane
        self.changingLane = True
        self.updateOnly()
        oldLane = self.lane
        newLane = self.lane.getLane(direction)
        try:
            self.processRef = self.env.process(changeLaneProcess(oldLane, newLane, Δt))
            yield self.processRef
            self.processRef = None
        except simpy.Interrupt:
            if self.traceInterrupt and self.traceOvertaking:
                self.trace(f"Overtaking interrupted at x={self.x0:7,.1f}m")
            # if interrupted go quickly back into old lane
            # but this is not interruptible
            self.updateOnly()
            # it is possible that there was an intermittent change lane event
            while self.lane != newLane and newLane is not None:
                newLane = newLane.next
                oldLane = oldLane.next
            self.processRef = None
            self.env.process(changeLaneProcess(newLane, oldLane, Δt/4, trace=False))
        self.changingLane = False    
        
    # smoothly adjust velocity by Δv over the time Δt
    def adjustVelocity(self, Δv, Δt):
        
        # smoothly adjust velocity by Δv over the time Δt
        def adjustVelocityProcess():
            
            self.updateOnly()
            
            if self.traceAdjustVelocity:
                self.trace(f"Adjusting Velocity from v={self.dx0:4,.1f}m/s by Δv={Δv:4,.1f}m/s over {Δt:4,.1f}s")
            
            minΔt = 0.1*Δt
            a = Δv/(Δt-minΔt)
            tt = Δt-2*minΔt
            
            self.dddx0 = (a-self.ddx0)/minΔt   
            yield self.env.timeout(minΔt)
        
            self.updateOnly()
            self.dddx0 = 0
            self.ddx0 = a
            yield self.env.timeout(tt)
        
            self.updateOnly()
            self.dddx0 = -a/minΔt
            yield self.env.timeout(minΔt)
        
            self.updateOnly()
            self.dddx0 = 0
            self.ddx0 = 0
                    
            if self.traceAdjustVelocity:
                self.trace(f"Adjusted  Velocity to   v={self.dx0:4,.1f}m/s")
        
        # start process
        self.current_target = self.dx0 + Δv
        self.processRef = self.env.process(adjustVelocityProcess())
        try:
            # wait for the process to finish
            yield self.processRef
        except simpy.Interrupt:
            # in case this has been interrupted
            if self.traceInterrupt:
                self.trace(f"Adjusting Velocity interrupted at v={self.dx0:4,.1f}m/s")
            pass
        self.current_target = None
        self.processRef = None

    def continueAtSameSpeed(self, Δt):
        
        def continueAtSameSpeedProcess():
            # don't change the current velocity
            self.dddx0 = 0
            self.ddx0 = 0
            yield self.env.timeout(Δt)
        
        # start process
        self.processRef = self.env.process(continueAtSameSpeedProcess())
        try:
            # wait for the process to finish
            yield self.processRef
        except simpy.Interrupt:
            # in case this has been interrupted
            if self.traceInterrupt:
                self.trace(f"Constant Velocity interrupted at v={self.dx0:4,.1f}m/s")
            pass
        self.processRef = None

    def interruptProcess(self):
        if self.processRef is not None and self.processRef.is_alive:
            self.processRef.interrupt('There are more important things to do...')

# %% [markdown]
# ### Property Surround

# %% [markdown]
# The Surround of a vehicle is a data structure that joins a number of properties and gives access to the next vehicles to the front, back, left and right side of the vehicle.
#
# * `leftLane` and `rightLane` are references to next `Lane` and are `None` is there is no lane to the left or right.
# * `left` and `right` are Boolean values that indicate that there is a vehicle in the critical region or not.
# * `front` (`leftFront`, `rightFront`) and `back` (`leftBack`, `rightBack`) are references to the `Vehicle` in the indicated region that is next to the current position. If there is no such vehicle, the references return `None`.
# * The limits of the relevant regions are defined based on the current position +/- a number of car lengths +/- a distance that is a multiple of the current velocity, defined as time constants.

# %% [markdown]
# <img src='Surround.png' width=600/>

# %%
class Surround:
    
    def __init__(self, vehicle):
        
        # For each of the directions None means that there is no 
        # vehicle in the immediate vicinity.
        # We initialise to a 'safe' value which can be easily detected
        # if something goes wrong
        
        self.vehicle = vehicle
            
        self.leftBack = None
        self.left = None
        self.leftFront = None
        self.back = None

        self.front = None
        self.rightBack = None
        self.right = None
        self.rightFront = None
        
        lane = vehicle.lane
        posFront = vehicle.pos
        posBack = vehicle.pos-vehicle.length
        if lane is not None:
            self.lane = lane
            self.front = lane.inFront(posFront, self.vehicle.far_away_in_front)
            self.back = lane.behind(posBack, self.vehicle.far_away_in_back)
            
            self.rightLane = lane.right
            if self.rightLane is not None:
                if vehicle.oldLane == lane.right:
                    # drifting left
                    self.right = vehicle
                    self.rightFront = self.rightLane.inFront(posFront, self.vehicle.far_away_in_front)
                    self.rightBack = self.rightLane.behind(posBack, self.vehicle.far_away_in_back)
                else:
                    right = self.rightLane.between(posBack-10, posFront+10)
                    if len(right)==0:
                        # self.right = None
                        self.rightFront = self.rightLane.inFront(posFront+10, self.vehicle.far_away_in_front)
                        self.rightBack = self.rightLane.behind(posBack-10, self.vehicle.far_away_in_back)
                    else:
                        self.right = right[0]
                        # self.rightFront = None
                        # self.rightBack = None

            self.leftLane = lane.left
            if self.leftLane is not None:
                if vehicle.oldLane == lane.left:
                    # drifting right
                    self.left = vehicle
                    self.leftFront = self.leftLane.inFront(posFront, self.vehicle.far_away_in_front)
                    self.leftBack = self.leftLane.behind(posBack, self.vehicle.far_away_in_back)
                else:
                    left = self.leftLane.between(posBack-10, posFront+10)
                    if len(left)==0:
                        # self.left = None
                        self.leftFront = self.leftLane.inFront(posFront+10, self.vehicle.far_away_in_front)
                        self.leftBack = self.leftLane.behind(posBack-10, self.vehicle.far_away_in_back)
                    else:
                        self.left = left[0]
                        # self.leftFront = None
                        # self.lefttBack = None
                    
        if vehicle.traceSurround:
            
            def s(vehicle):
                if vehicle is None:
                    return " "
                elif type(vehicle) is list:
                    if len(vehicle)==1:
                        return s(vehicle[0])
                    else:
                        res = "["
                        for v in vehicle:
                            if len(res)>1:
                                res += ','
                            res+=s(v)
                        res += "]"
                        return res
                else:
                    return f"{vehicle.id:d}"

            print(f"surround t={self.vehicle.env.now:6.2f} " +
                  "|" +
                  ("" if self.leftLane is None else 
                      f"|{s(self.leftBack):s}>{s(self.left):s}>{s(self.leftFront):s}") +
                  f"|{s(self.back):s}>{s(self.vehicle):s}>{s(self.front):s}|" +
                  ("" if self.rightLane is None else
                      f"{s(self.rightBack):s}>{s(self.right):s}>{s(self.rightFront):s}|") +
                  "|"
                 )

# %% [markdown]
# # Recorder

# %% [markdown]
# [TOC](#Table-of-Contents)

# %%
class Recorder:
    
    def __init__(self, startTime=0, stopTime=0, timeStep=1):
        
        global VEHICLE_ID, LANE_ID
        VEHICLE_ID = 0
        LANE_ID = 0
        
        self.env = simpy.Environment()
        self.ps = []
        self.startTime = startTime
        self.stopTime = stopTime
        self.timeStep = timeStep
        self.data = pd.DataFrame(columns=['t', 'x', 'v', 'a', 'id', 'lane', 'oldLane', 'pos', 'event'])

    # runs the simulation
    def run(self):
        self.env.process(self.process())
        self.env.run(self.stopTime+self.timeStep)
    
    def process(self):
        yield self.env.timeout(self.startTime-self.env.now)
        while self.env.now <= self.stopTime:
            self.record()     
            yield self.env.timeout(self.timeStep)
            
    def startRecording(self, p):
        self.ps.append(p)
        self.record(p, event='start')
        
    def stopRecording(self, p):
        self.ps.remove(p)
        
    def record(self, p=None, event='timer'):
        if p is not None:
            if p.updateOnly() or event!='timer':
                laneId = -1 if p.lane is None else p.lane.id
                oldLaneId = -1 if p.oldLane is None else p.oldLane.id
                ix = len(self.data)
                self.data.loc[ix]=[self.env.now, p.x0, p.dx0, p.ddx0, p.id, \
                                   laneId, oldLaneId, p.pos, event]
                if event=='timer':
                    p.update()
        else:
            for p in self.ps:
                self.record(p, event)

    ## additional code: record lane information
    def recordLane(self, lane):
        ix = len(self.data)
        self.data.loc[ix]=[0, 0, 0, 0, 0, lane.id, -1, lane.length, 'lane info'] 

    ## additional code: record lane information
    def getLaneLength(self, laneId):
        lanes = self.data[self.data.event=='lane info']
        lane = lanes[lanes.lane==laneId]
        return lane.pos.iloc[0]
    
    def saveData(self, filename):
        self.data.to_csv(filename, index=False)
        
    def getData(self):
        return self.data.copy(deep=True)
    
    def getEvents(self):
        return self.data[self.data.event!='timer'].copy(deep=True)
    
    ## new code: computes traffic flow in vehicles/h at the end of a given lane
    ## based on 'leave lane' events proper (i.e. excluding overtaking)
    def flow(self, lane):
        df = self.data[self.data.event=='leave lane']
        df = df[df.lane==lane]
        if len(df)>1:
            # compensate for lane filling late or early running dry
            f = (len(df)-1)*3600/(df.t.max()-df.t.min())
            return round(f, 2)
        else:
            return 0

    ## new code: computes the average travelling time through a lane segment
    def avgTravelTime(self, laneId):
        d0 = self.data[self.data.event=='enter lane']
        d0 = d0[d0.lane==laneId]
        d1 = self.data[self.data.event=='leave lane']
        d1 = d1[d1.lane==laneId]
        times = []
        id0 = d0.id.unique()
        id1 = d1.id.unique()
        for id in id0:
            t0 = d0.t[d0.id==id].min()
            if id in id1:
                t1 = d1.t[d1.id==id].max()
                times += [ t1-t0 ]
        avg = 0
        if len(times)>0:
            avg = round(sum(times)/len(times), 2)
        return avg

    def avgSpeed(self, laneId):
        return round(3.6*self.getLaneLength(laneId)/self.avgTravelTime(laneId),2)
        
        
    ## new code: computes traffic density in vehicles/km for a given lane
    ## at a given moment in time. When no time is specified it returns a
    ## list of traffic densities over time.
    def density(self, laneId, time=None):
        timerEvents = self.data[self.data.event=='timer']
        times = timerEvents.t.unique()
        laneEvents = timerEvents[timerEvents.lane==laneId]
        laneLength = self.getLaneLength(laneId)
        
        if time is None:
            densities = []
            for t in times:
                events = laneEvents[laneEvents.t==t]
                d = len(events)*1000/laneLength
                densities.append(round(d,2))
            return sum(densities)/len(densities)
        
        # find the timestamp nearest to the requested time
        if time in times:
            t = time
        else:
            # take the nearest point in time
            diff = list((times-time)**2)
            t = times[diff.index(min(diff))]
        events = laneEvents[laneEvents.t==t]
        d = len(events)*1000/laneLength
        return round(d,2)
    
    def plot(self, x, y, 
             vehicles=None, style='', lw=1, decoration=True,
             x0=None, x1=None, y0=None, y1=None, fillColor=None, 
             xmin=None, xmax=None, ymin=None, ymax=None):
        columns = ['t', 'x', 'v', 'a']
        labels = ['Time [s]', 'Position [m]', 'Velocity [m/s]', 'Acceleration [m/s²]']
        xindex = columns.index(x)
        yindex = columns.index(y)
        
        plt.figure(figsize=(5, 3), dpi=120)
        if xmin is not None and xmax is not None:
            plt.xlim((xmin, xmax))
        if ymin is not None and ymax is not None:
            plt.ylim((ymin, ymax))
        
        if vehicles is None:
            vehicles = list(self.data.id.unique())
        for id in vehicles:
            df = self.data[self.data.id==id]
            plt.plot(x, y, style, lw=lw, data=df)
            plt.xlabel(labels[xindex])
            plt.ylabel(labels[yindex])
            
            if not decoration:
                continue
            
            # use small red circle to indicate emergency braking
            dc = df[df.event=='brake']
            for i in range(len(dc)):
                X = dc.iloc[i, xindex]
                Y = dc.iloc[i, yindex]
                plt.plot([X], [Y], 'ro')
                            
            db = df[df.event=='brake end']
            for i in range(len(db)):
                X = db.iloc[i, xindex]
                Y = db.iloc[i, yindex]
                plt.plot([X], [Y], marker='o', mec='r', fillstyle='none')

            # use black 'x' as crash indicator
            dc = df[df.event=='crash']
            for i in range(len(dc)):
                X = dc.iloc[i, xindex]
                Y = dc.iloc[i, yindex]
                plt.plot([X], [Y], 'xk')
                
            # use black Diamond to indicate that
            # a vehicle ran out of track
            dc = df[df.event=='end']
            for i in range(len(dc)):
                X = dc.iloc[i, xindex]
                Y = dc.iloc[i, yindex]
                plt.plot([X], [Y], 'Dk')
                
            # use black right pointing full triangle
            # to indicate that a vehicle started
            #  changing into the fast lane
            dc = df[df.event=='change fast']
            for i in range(len(dc)):
                X = dc.iloc[i, xindex]
                Y = dc.iloc[i, yindex]
                plt.plot([X], [Y], '>k')
                
            # use black right pointing hollow triangle
            # to indicate that a vehicle has finished
            # changing into the fast lane
            dc = df[df.event=='done change fast']
            for i in range(len(dc)):
                X = dc.iloc[i, xindex]
                Y = dc.iloc[i, yindex]
                plt.plot([X], [Y], marker='>', mec='k', fillstyle='none')

            # use black left pointing full triangle
            # to indicate that a vehicle started
            #  changing into the slow lane
            dc = df[df.event=='change slow']
            for i in range(len(dc)):
                X = dc.iloc[i, xindex]
                Y = dc.iloc[i, yindex]
                plt.plot([X], [Y], '<k')
                
            # use black left pointing hollow triangle
            # to indicate that a vehicle has finished
            # changing into the slow lane
            dc = df[df.event=='done change slow']
            for i in range(len(dc)):
                X = dc.iloc[i, xindex]
                Y = dc.iloc[i, yindex]
                plt.plot([X], [Y], marker='<', mec='k', fillstyle='none')
            
        # fill area with background color
        if fillColor is not None:
            if x0 is None:
                x0=self.data[x].min()
            if x1 is None:
                x1=self.data[x].max()
            if y0 is None:
                y0=self.data[y].min()
            if y1 is None:
                y1=self.data[y].max()
            plt.fill_between( [x0, x1], [y0, y0], [y1, y1], color=fillColor)
            
        plt.grid(True)

# %% [markdown]
# ## Load Data

# %%
def loadData(filename):  
    data = pd.read_csv(filename)
    r = Recorder()
    if list(data.columns) == list(r.data.columns):
        r.data = data
        return r
    else:
        return None

# %% [markdown]
# ## Comparing Data

# %%
def sameData(r1, r2):
    try:
        return all(r1.getData() == r2.getData())
    except ValueError:
        return False

# %% [markdown]
# # Testing New Functionality

# %%
VMAX = 120/3.6

N_l = 35 # number of vehicles in the left lane 
IAT_l = 3 # average interarrival time left lane
N_r = 20 # number of vehicles in the left lane 
IAT_r = 5 # average interarrival time left lane

random.seed(13)

iat_l = [ rv(IAT_l, delta=0.4*IAT_l) for i in range(N_l) ]
iat_r = [ rv(IAT_r, delta=0.4*IAT_r) for i in range(N_r) ]

rec = Recorder(0, 600, 1)

l = Lane(rec, 1000)
while l.totalLength()<3000:
    l.extend(Lane(rec, 1000))
r = l.widenRight()

print("L:", l)
print("R:", r)

# fill left lane
t = 0
for i in range(N_l):
    t += iat_l[i]
    v = Vehicle(rec, startingLane=l, t0=t, dx0=VMAX, vmax=VMAX)
    v.traceCrash = True
    v.traceOvertaking = True

# fill right lane
t = 0
for i in range(N_r):
    t += iat_r[i]
    v = Vehicle(rec, startingLane=r, t0=t, dx0=VMAX, vmax=VMAX)
    v.traceCrash = True
    v.traceOvertaking = True
    
rec.run()
# Out:
# L: [00 x=0.0m l=1000.0m L:-- R:03]-[01 x=1000.0m l=1000.0m L:-- R:04]-[02 x=2000.0m l=1000.0m L:-- R:05]
# R: [03 x=0.0m l=1000.0m L:00 R:--]-[04 x=1000.0m l=1000.0m L:01 R:--]-[05 x=2000.0m l=1000.0m L:02 R:--]

# %%
rec.plot('t', 'x')

# %%
rec.plot('t', 'x', ymin=2800, ymax=3100)

# %% [markdown]
# ## Traffic Flow in veh/h

# %% [markdown]
# The traffic flow at the end of lane segments for the **left lane**:

# %%
rec.flow(0), rec.flow(1), rec.flow(2)
# Out:
# (1188.35, 1200.0, 1189.23)

# %% [markdown]
# The traffic flow at the end of lane segments for the **right lane**:

# %%
rec.flow(3), rec.flow(4), rec.flow(5)
# Out:
# (727.66, 720.0, 720.0)

# %% [markdown]
# Total traffic flow at the end of lane segments for **both lane**:

# %%
rec.plot('t', 'x', xmin=50, xmax=100, ymin=0, ymax=1000, style='b')

# %% [markdown]
# Combined Traffic flow reading at 1000m (i.e. the end of lane 0 and lane 3) is 26 vehicles over 50 sec, i.e. `3600/50*26 veh/h` = `1908 veh/h`.

# %% [markdown]
# The statistics reports:

# %%
rec.flow(0)+rec.flow(3)
# Out:
# 1916.0099999999998

# %% [markdown]
# ## Traffic Density im veh/km

# %%
rec.plot('t', 'x', xmin=50, xmax=100, ymin=0, ymax=1000, style='b')

# %% [markdown]
# Combined Traffic density reading of 1000m at time 100s is `17 veh/km`.

# %% [markdown]
# The statistics reports:

# %%
rec.density(0, 50) + rec.density(3, 50)
# Out:
# 17.0

# %% [markdown]
# ## Average Travel Times in s

# %%
rec.avgTravelTime(0)
# Out:
# 30.41

# %%
rec.avgTravelTime(3)
# Out:
# 30.47

# %% [markdown]
# ## Average Speed in km/h

# %%
rec.avgSpeed(0)
# Out:
# 118.38

# %%
rec.avgSpeed(3)
# Out:
# 118.15

# %% [markdown]
# ## Fundamental Law

# %%
rec.density(0, 50)*rec.avgSpeed(0)
# Out:
# 1302.1799999999998

# %%
rec.density(3, 20)*rec.avgSpeed(3)
# Out:
# 354.45000000000005

# %%
rec.density(0, 50)*rec.avgSpeed(0) + rec.density(3, 50)*rec.avgSpeed(3)
# Out:
# 2011.08

# %%
rec.flow(0)+rec.flow(3)
# Out:
# 1916.0099999999998

# %% [markdown]
# Note a **density inaccuracy** of `1 veh/km` corresponds at a speed of `120km/h` to a **flow inaccuracy** of `120 veh/h`.

# %% [markdown]
# # Simulation

# %%
def simulation(N, IAT):
    VMAX = 120/3.6

    rec = Recorder(0, 150, 1)
    iat = [ rv(IAT, delta=0.4*IAT) for i in range(N) ]

    l = Lane(rec, 1000)
    while l.totalLength()<3000:
        l.extend(Lane(rec, 1000))
    r = l.widenRight()

    t = 0
    for i in range(N):
        t += iat[i]
        v = Vehicle(rec, startingLane=l if i%2==0 else r, t0=t, dx0=VMAX, vmax=VMAX)
        v.traceCrash = True
        v.traceOvertaking = True
    rec.run()
    return rec.flow(0)+rec.flow(3)

# %%
simulation(20, 2)
# Out:
# 1801.3899999999999

# %%
simulation(20, 1.6)
# Out:
# 2125.16

# %%
simulation(20, 0.5)
# Out:
# 6839.1

# %% [markdown]
# # Verification

# %% [markdown]
# [TOC](#Table-of-Contents)

# %% [markdown]
# ## Construction of Motorway Segments

# %% [markdown]
# [TOC](#Table-of-Contents)

# %% [markdown]
# ### Testing the Construction of Single Lane Motorway

# %%
rec = Recorder()
l = Lane(rec, 1000)
while l.totalLength()<5000:
    l.extend(Lane(rec, 1000))
print(l)
# Out:
# [00 x=0.0m l=1000.0m L:-- R:--]-[01 x=1000.0m l=1000.0m L:-- R:--]-[02 x=2000.0m l=1000.0m L:-- R:--]-[03 x=3000.0m l=1000.0m L:-- R:--]-[04 x=4000.0m l=1000.0m L:-- R:--]

# %% [markdown]
# ### Testing the Construction of Multilane Motorway Segments

# %%
rec = Recorder()
l = Lane(rec, 1000)
while l.totalLength()<5000:
    l.extend(Lane(rec, 1000))
r = l.widenRight()
print("Left Lane: ", l)
print("Right Lane:", r)
# Out:
# Left Lane:  [00 x=0.0m l=1000.0m L:-- R:05]-[01 x=1000.0m l=1000.0m L:-- R:06]-[02 x=2000.0m l=1000.0m L:-- R:07]-[03 x=3000.0m l=1000.0m L:-- R:08]-[04 x=4000.0m l=1000.0m L:-- R:09]
# Right Lane: [05 x=0.0m l=1000.0m L:00 R:--]-[06 x=1000.0m l=1000.0m L:01 R:--]-[07 x=2000.0m l=1000.0m L:02 R:--]-[08 x=3000.0m l=1000.0m L:03 R:--]-[09 x=4000.0m l=1000.0m L:04 R:--]

# %%
rec = Recorder()
c = Lane(rec, 1000)
while c.totalLength()<4000:
    c.extend(Lane(rec, 1000))
l = c.widenLeft()
r = c.widenRight()
print("Left Lane:  ", l)
print("Centre Lane:", c)
print("Right Lane: ", r)
# Out:
# Left Lane:   [04 x=0.0m l=1000.0m L:-- R:00]-[05 x=1000.0m l=1000.0m L:-- R:01]-[06 x=2000.0m l=1000.0m L:-- R:02]-[07 x=3000.0m l=1000.0m L:-- R:03]
# Centre Lane: [00 x=0.0m l=1000.0m L:04 R:08]-[01 x=1000.0m l=1000.0m L:05 R:09]-[02 x=2000.0m l=1000.0m L:06 R:10]-[03 x=3000.0m l=1000.0m L:07 R:11]
# Right Lane:  [08 x=0.0m l=1000.0m L:00 R:--]-[09 x=1000.0m l=1000.0m L:01 R:--]-[10 x=2000.0m l=1000.0m L:02 R:--]-[11 x=3000.0m l=1000.0m L:03 R:--]

# %% [markdown]
# ### Construction of Multilane Motorway Segments with Speed Limit

# %%
rec = Recorder()
l = Lane(rec, 1000)
l.extend(Lane(rec, 1500, speedLimit=80))
r = l.widenRight()
print("Left Lane: ", l)
print("Right Lane:", r)
# Out:
# Left Lane:  [00 x=0.0m l=1000.0m L:-- R:02]-[01 x=1000.0m l=1500.0m L:-- R:03 speedLimit:80km/h]
# Right Lane: [02 x=0.0m l=1000.0m L:00 R:--]-[03 x=1000.0m l=1500.0m L:01 R:-- speedLimit:80km/h]

# %% [markdown]
# ### Constructing a Motorway On-Ramp

# %%
rec = Recorder()

l = Lane(rec, 700)
l1 = Lane(rec, 300)

l.extend(l1)
l.extend(Lane(rec, 1000))
r = l.widenRight()

onRamp = Lane(rec, 700)
mergeLane = Lane(rec, 300, merge='R')
onRamp.extend(mergeLane)

l1.attachLeft(mergeLane)
l1.left = None  # don't move from the left lane onto the merge lane

print("On-Ramp:", onRamp)
print("      L:", l)
print("      R:", r)
# Out:
# On-Ramp: [06 x=0.0m l=700.0m L:-- R:--]-[07 x=700.0m l=300.0m L:-- R:01]\
#       L: [00 x=0.0m l=700.0m L:-- R:03]-[01 x=700.0m l=300.0m L:-- R:04]-[02 x=1000.0m l=1000.0m L:-- R:05]
#       R: [03 x=0.0m l=700.0m L:00 R:--]-[04 x=700.0m l=300.0m L:01 R:--]-[05 x=1000.0m l=1000.0m L:02 R:--]

# %% [markdown]
# ## Controlled Lane Change

# %% [markdown]
# [TOC](#Table-of-Contents)

# %%
rec = Recorder(0, 25, 0.5)
l = Lane(rec, 500)
r = Lane(rec, 500)
l.attachRight(r)
v = Vehicle(rec, startingLane=l, dx0=20, t=[2, 2, 10, 2, 5], v=[20, 'R', 20, 'L', 30])
v.traceSurround = True
rec.run()
# Out:
# surround t=  0.00 || >0> | > > ||
# surround t=  0.50 || >0> | > > ||
# surround t=  1.00 || >0> | > > ||
# surround t=  1.50 || >0> | > > ||
# surround t=  2.00 || >0> | > > ||
# surround t=  2.50 || >0> | >0> ||
# surround t=  3.00 || >0> | >0> ||
# surround t=  3.50 || >0> | >0> ||
# surround t=  4.00 || > > | >0> ||
# surround t=  4.50 || > > | >0> ||
# surround t=  5.00 || > > | >0> ||
# surround t=  5.50 || > > | >0> ||
# surround t=  6.00 || > > | >0> ||
# surround t=  6.50 || > > | >0> ||
# surround t=  7.00 || > > | >0> ||
# surround t=  7.50 || > > | >0> ||
# surround t=  8.00 || > > | >0> ||
# surround t=  8.50 || > > | >0> ||
# surround t=  9.00 || > > | >0> ||
# surround t=  9.50 || > > | >0> ||
# surround t= 10.00 || > > | >0> ||
# surround t= 10.50 || > > | >0> ||
# surround t= 11.00 || > > | >0> ||
# surround t= 11.50 || > > | >0> ||
# surround t= 12.00 || > > | >0> ||
# surround t= 12.50 || > > | >0> ||
# surround t= 13.00 || > > | >0> ||
# surround t= 13.50 || > > | >0> ||
# surround t= 14.00 || > > | >0> ||
# surround t= 14.50 || >0> | >0> ||
# surround t= 15.00 || >0> | >0> ||
# surround t= 15.50 || >0> | >0> ||
# surround t= 16.00 || >0> | > > ||
# surround t= 16.50 || >0> | > > ||
# surround t= 17.00 || >0> | > > ||
# surround t= 17.50 || >0> | > > ||
# surround t= 18.00 || >0> | > > ||
# surround t= 18.50 || >0> | > > ||
# surround t= 19.00 || >0> | > > ||
# surround t= 19.50 || >0> | > > ||
# surround t= 20.00 || >0> | > > ||
# surround t= 20.50 || >0> | > > ||
# surround t= 21.00 || >0> | > > ||
# surround t= 21.50 || >0> | > > ||
# surround t= 22.00 || >0> | > > ||

# %%
rec.getData()
# Out:
#        t       x          v         a id lane oldLane     pos  \
# 0      0       0          0         0  0    0      -1     500
# 1      0       0          0         0  0    1      -1     500
# 2      0       0         20         0  0   -1      -1       0
# 3      0       0         20         0  0    0      -1       0
# 4      0       0         20         0  0    0      -1       0
# 5    0.5    10.0       20.0       0.0  0    0      -1    10.0
# 6    1.0    20.0       20.0       0.0  0    0      -1    20.0
# 7    1.5    30.0       20.0       0.0  0    0      -1    30.0
# 8    2.0    40.0       20.0       0.0  0    0      -1    40.0
# 9      2    40.0       20.0       0.0  0    0      -1    40.0
# 10     2    40.0       20.0       0.0  0    1       0    40.0
# 11   2.5   50.12       20.5       1.0  0    1       0   50.12
# 12   3.0   60.49       21.0       1.0  0    1       0   60.49
# 13   3.5   71.12       21.5       1.0  0    1       0   71.12
# 14     4    82.0       22.0       1.0  0    1       0    82.0
# 15     4    82.0       22.0         0  0    1      -1    82.0
# 16   4.0    82.0       22.0         0  0    1      -1    82.0
# 17   4.5    93.0  21.972222 -0.111111  0    1      -1    93.0
# 18   5.0  103.97  21.888889 -0.222222  0    1      -1  103.97
# 19   5.5  114.89  21.777778 -0.222222  0    1      -1  114.89
# 20   6.0  125.75  21.666667 -0.222222  0    1      -1  125.75
# 21   6.5  136.56  21.555556 -0.222222  0    1      -1  136.56
# 22   7.0  147.31  21.444444 -0.222222  0    1      -1  147.31
# 23   7.5   158.0  21.333333 -0.222222  0    1      -1   158.0
# 24   8.0  168.64  21.222222 -0.222222  0    1      -1  168.64
# 25   8.5  179.22  21.111111 -0.222222  0    1      -1  179.22
# 26   9.0  189.75       21.0 -0.222222  0    1      -1  189.75
# 27   9.5  200.22  20.888889 -0.222222  0    1      -1  200.22
# 28  10.0  210.64  20.777778 -0.222222  0    1      -1  210.64
# 29  10.5   221.0  20.666667 -0.222222  0    1      -1   221.0
# 30  11.0  231.31  20.555556 -0.222222  0    1      -1  231.31
# 31  11.5  241.56  20.444444 -0.222222  0    1      -1  241.56
# 32  12.0  251.75  20.333333 -0.222222  0    1      -1  251.75
# 33  12.5  261.89  20.222222 -0.222222  0    1      -1  261.89
# 34  13.0  271.97  20.111111 -0.222222  0    1      -1  271.97
# 35  13.5   282.0  20.027778 -0.111111  0    1      -1   282.0
# 36  14.0   292.0       20.0         0  0    1      -1   292.0
# 37  14.0   292.0       20.0         0  0    1      -1   292.0
# 38  14.0   292.0       20.0         0  0    0       1   292.0
# 39  14.5  302.12       20.5       1.0  0    0       1  302.12
# 40  15.0   312.5       21.0       1.0  0    0       1   312.5
# 41  15.5  323.12       21.5       1.0  0    0       1  323.12
# 42  16.0   334.0       22.0       1.0  0    0       1   334.0
# 43  16.0   334.0       22.0         0  0    0      -1   334.0
# 44  16.0   334.0       22.0         0  0    0      -1   334.0
# 45  16.5  345.07  22.444444  1.777778  0    0      -1  345.07
# 46  17.0  356.51  23.333333  1.777778  0    0      -1  356.51
# 47  17.5   368.4  24.222222  1.777778  0    0      -1   368.4
# 48  18.0  380.73  25.111111  1.777778  0    0      -1  380.73
# 49  18.5  393.51       26.0  1.777778  0    0      -1  393.51
# 50  19.0  406.73  26.888889  1.777778  0    0      -1  406.73
# 51  19.5   420.4  27.777778  1.777778  0    0      -1   420.4
# 52  20.0  434.51  28.666667  1.777778  0    0      -1  434.51
# 53  20.5  449.07  29.555556  1.777778  0    0      -1  449.07
# 54  21.0   464.0       30.0         0  0    0      -1   464.0
# 55  21.5   479.0       30.0       0.0  0    0      -1   479.0
# 56  22.0   494.0       30.0       0.0  0    0      -1   494.0
# 57  22.5   509.0       30.0       0.0  0    0      -1   509.0
# 58  22.5   509.0       30.0       0.0  0   -1      -1   509.0
#
#                event
# 0          lane info
# 1          lane info
# 2              start
# 3         enter lane
# 4              timer
# 5              timer
# 6              timer
# 7              timer
# 8              timer
# 9        change fast
# 10      enter lane 1
# 11             timer
# 12             timer
# 13             timer
# 14      leave lane 0
# 15  done change fast
# 16             timer
# 17             timer
# 18             timer
# 19             timer
# 20             timer
# 21             timer
# 22             timer
# 23             timer
# 24             timer
# 25             timer
# 26             timer
# 27             timer
# 28             timer
# 29             timer
# 30             timer
# 31             timer
# 32             timer
# 33             timer
# 34             timer
# 35             timer
# 36             timer
# 37       change slow
# 38      enter lane 0
# 39             timer
# 40             timer
# 41             timer
# 42      leave lane 1
# 43  done change slow
# 44             timer
# 45             timer
# 46             timer
# 47             timer
# 48             timer
# 49             timer
# 50             timer
# 51             timer
# 52             timer
# 53             timer
# 54             timer
# 55             timer
# 56             timer
# 57        leave lane
# 58               end

# %%
rec.plot('t', 'x')

# %% [markdown]
# ## Automatic Overtaking

# %% [markdown]
# [TOC](#Table-of-Contents)

# %%
rec = Recorder(0, 100, 0.5)
l = Lane(rec, 1000)
r = Lane(rec, 1000)
l.attachRight(r)
v0 = Vehicle(rec, startingLane=l, t0=0, dx0=20)
v1 = Vehicle(rec, startingLane=l, t0=10, dx0=30)
v1.traceOvertaking = True
rec.run()
# Out:
# t=   15.0s x=  150.0m v1 Overtaking v0  at x=  150.0m
# t=   31.0s x=  678.0m v1 Overtaking done return to slow lane at x=  678.0m

# %%
rec.plot('t', 'x')

# %%
rec.getEvents()
# Out:
#         t       x     v    a id lane oldLane     pos             event
# 0       0       0     0    0  0    0      -1    1000         lane info
# 1       0       0     0    0  0    1      -1    1000         lane info
# 2       0       0    20    0  0   -1      -1       0             start
# 3       0       0    20    0  0    0      -1       0        enter lane
# 24     10       0    30    0  1   -1      -1       0             start
# 25     10       0    30    0  1    0      -1       0        enter lane
# 48   15.0   150.0  30.0  0.0  1    0      -1   150.0       change fast
# 49   15.0   150.0  30.0  0.0  1    1       0   150.0      enter lane 1
# 60   18.0   244.5  33.0  1.0  1    1       0   244.5      leave lane 0
# 61   18.0   244.5  33.0    0  1    1      -1   244.5  done change fast
# 104  28.0   574.5  33.0  0.0  1    1      -1   574.5       change slow
# 105  28.0   574.5  33.0  0.0  1    0       1   574.5      enter lane 0
# 116  31.0   678.0  36.0  1.0  1    0       1   678.0      leave lane 1
# 117  31.0   678.0  36.0    0  1    0      -1   678.0  done change slow
# 155  40.0  1002.0  36.0  0.0  1    0      -1  1002.0        leave lane
# 156  40.0  1002.0  36.0  0.0  1   -1      -1  1002.0               end
# 176  50.0  1000.0  20.0  0.0  0    0      -1  1000.0        leave lane
# 177  50.0  1000.0  20.0  0.0  0   -1      -1  1000.0               end

# %% [markdown]
# ## One Vehicle Fixed Speed Profile

# %% [markdown]
# [TOC](#Table-of-Contents)

# %% [markdown]
# ### Accelleration Only (Short Distance)

# %%
rec = Recorder(0, 10, 0.1)
l = Lane(rec, 500)
Vehicle(rec, startingLane=l, dx0=10, t=[10], v=[30])
rec.run()

# %%
rec.getData()
# Out:
#         t       x          v         a id lane oldLane     pos       event
# 0       0       0          0         0  0    0      -1     500   lane info
# 1       0       0         10         0  0   -1      -1       0       start
# 2       0       0         10         0  0    0      -1       0  enter lane
# 3       0       0         10         0  0    0      -1       0       timer
# 4     0.1     1.0  10.011111  0.222222  0    0      -1     1.0       timer
# ..    ...     ...        ...       ... ..  ...     ...     ...         ...
# 99    9.6  188.02  29.822222  0.888889  0    0      -1  188.02       timer
# 100   9.7  191.01       29.9  0.666667  0    0      -1  191.01       timer
# 101   9.8   194.0  29.955556  0.444444  0    0      -1   194.0       timer
# 102   9.9   197.0  29.988889  0.222222  0    0      -1   197.0       timer
# 103  10.0   200.0       30.0       0.0  0    0      -1   200.0       timer
#
# [104 rows x 9 columns]

# %%
rec.plot('t', 'x')

# %%
rec.plot('t', 'v')

# %%
rec.plot('t', 'a')

# %% [markdown]
# ### Accelleration and Cruising (Longer Distance)

# %% [markdown]
# [TOC](#Table-of-Contents)

# %%
rec = Recorder(0, 200, 1)
l = Lane(rec, 1000)
l.extend(Lane(rec, 2000))
Vehicle(rec, startingLane=l, dx0=10, t=[10, 90], v=[30, 30])
rec.run()

# %%
data = rec.getData()
data[data.event!='timer']
# Out:
#        t       x     v    a id lane oldLane     pos       event
# 0      0       0     0    0  0    0      -1    1000   lane info
# 1      0       0     0    0  0    1      -1    2000   lane info
# 2      0       0    10    0  0   -1      -1       0       start
# 3      0       0    10    0  0    0      -1       0  enter lane
# 41    37  1010.0  30.0  0.0  0    0      -1  1010.0  leave lane
# 42    37  1010.0  30.0  0.0  0    1      -1    10.0  enter lane
# 110  104  3020.0  30.0    0  0    1      -1  2020.0  leave lane
# 111  104  3020.0  30.0    0  0   -1      -1  2020.0         end

# %%
rec.plot('t', 'x')

# %%
rec.plot('t', 'v')

# %%
rec.plot('t', 'a')

# %% [markdown]
# ### Accelleration and Decelleration

# %% [markdown]
# [TOC](#Table-of-Contents)

# %% [markdown]
# Test the movement of a single point with an initial speed is 10m/s, accellerating over the first 20s to 30m/s, staying at that speed for 30sec and than slowly decellerating over 40s to 20m/s.
#
# This would normally take 2400m. Experiment with shorter lanes to see how the system behaves, when a vehicle reaches the end of track.

# %%
rec = Recorder(0, 100, 1)
l = Lane(rec, 1000)
l.extend(Lane(rec, 1500))
Vehicle(rec, startingLane = l, dx0=10, t=[20, 20, 40, 20], v=[30, 30, 20, 20])
rec.run()

# %%
rec.plot('t', 'x')

# %%
rec.plot('t', 'v')

# %%
rec.plot('t', 'a')

# %% [markdown]
# ## Multiple Vehicles with Fixed Speed Profile

# %% [markdown]
# [TOC](#Table-of-Contents)

# %%
N = 8
DT = 7
rec = Recorder(0, 150, 2)
l = Lane(rec, 1000)
l.extend(Lane(rec, 1000))
for i in range(N):
    Vehicle(rec, startingLane=l, t0=i*DT, dx0=10, 
            t=[20, 20, 40, 200], v=[35-2*i, 35-2*i, 15-2*i, 15-2*i])
rec.run()

# %%
rec.plot('t', 'x')

# %%
rec.plot('t', 'v')

# %%
N = 5
DT = 7
rec = Recorder(0, 500, 2)
l = Lane(rec, 10000)
l.extend(Lane(rec, 10000))
r = l.widenRight()
for i in range(N):
    v = Vehicle(rec, startingLane=l, t0=i*DT, dx0=10, 
            t=[20, 20, 40, 200], v=[35+2*i, 35+2*i, 15+2*i, 15+2*i])
    v.traceOvertaking = True
    v.traceBraking = True
    v.traceCrash = True
rec.run()
# Out:
# t=   46.0s x=1,173.0m v1 Overtaking v0  at x=1,173.0m
# t=   64.0s x=1,452.4m v3 Overtaking v2  at x=1,452.4m
# t=   73.0s x=2,100.8m v1 Overtaking done return to slow lane at x=2,100.8m
# t=   78.0s x=2,071.2m v2 Braking from v=26.8m/s to 15.3m/s
# t=   81.1s x=2,135.5m v2 Braking end  v=15.3m/s
# t=   84.0s x=2,023.2m v4 Overtaking v2  at x=2,023.2m
# t=   97.0s x=2,519.5m v4 Overtaking done return to slow lane at x=2,519.5m
# t=  101.0s x=3,019.9m v3 Overtaking done return to slow lane at x=3,019.9m
# t=  108.0s x=2,971.8m v4 Overtaking v1  at x=2,971.8m
# t=  125.0s x=3,721.9m v4 Overtaking done return to slow lane at x=3,721.9m
# t=  170.0s x=5,842.3m v4 Overtaking v3  at x=5,842.3m
# t=  207.0s x=7,696.7m v4 Overtaking done return to slow lane at x=7,696.7m

# %%
rec.plot('t', 'x')

# %%
rec.plot('t', 'x', xmin=40, xmax=120, ymin=0, ymax=4000)

# %% [markdown]
# ## Testing Vehicles with Random Speed Profile

# %% [markdown]
# [TOC](#Table-of-Contents)

# %% [markdown]
# ### A Single Vehicle of Varying Speed

# %% [markdown]
# [TOC](#Table-of-Contents)

# %%
VMAX = 120/3.6
random.seed(13)
rec = Recorder(0, 1000, 1)

l = Lane(rec, 1000)
while l.totalLength()<40000:
    l.extend(Lane(rec, 1000))
    
Vehicle(rec, startingLane=l, t0=0, dx0=10, vmax=VMAX)
rec.run()

# %%
rec.plot('t', 'x')

# %%
rec.plot('t', 'v')

# %%
rec.plot('t', 'a')

# %%
rec.plot('x', 'v')

# %%
rec.plot('x', 'a')

# %% [markdown]
# ### Multiple Vehicles with Varying Speeds

# %% [markdown]
# [TOC](#Table-of-Contents)

# %%
VMAX = 120/3.6
N = 5 # number of points
DT = 10 # time difference between start
random.seed(13)
rec = Recorder(0, 1000, 1)

l = Lane(rec, 1000)
while l.totalLength()<35000:
    l.extend(Lane(rec, 1000))
    
for i in range(N):
    Vehicle(rec, startingLane=l, t0=i*DT, vmax=VMAX)
    
rec.run()

# %%
rec.plot('t', 'x')

# %% [markdown]
# The position over time plots show nearly parallel lines since the speed varies tightly around the target maximum speed of 120km/h:

# %%
rec.plot('t', 'v')

# %% [markdown]
# There is only marginal accelleration and decelleration over time:

# %%
rec.plot('t', 'a')

# %%
rec.plot('x', 'v')

# %%
rec.plot('x', 'a')

# %%
rec.plot('v', 'a', vehicles=[0,1])

# %%
rec.plot('v', 'a', vehicles=[2,3,4])

# %% [markdown]
# ## Multiple Vehicles with Fixed Speed Profile (Emergency Braking)

# %% [markdown]
# [TOC](#Table-of-Contents)

# %% [markdown]
# ### Two Vehicles on a Single Lane

# %%
rec = Recorder(0, 150, 1)
l = Lane(rec, 2000)
Vehicle(rec, startingLane = l, t0=0, dx0=10)
Vehicle(rec, startingLane = l, t0=20, dx0=20)
rec.run()

# %%
rec.plot('t', 'x')

# %%
rec.plot('t', 'x', xmin=20, xmax=50, ymin=0, ymax=600)

# %% [markdown]
# ### Same Scenario on Two Lanes

# %%
rec = Recorder(0, 150, 1)
l = Lane(rec, 2000)
r = l.widenRight()
Vehicle(rec, startingLane = l, t0=0, dx0=10)
Vehicle(rec, startingLane = l, t0=20, dx0=20)
rec.run()

# %%
rec.plot('t', 'x')

# %% [markdown]
# ### Multiple Vehicles on a Single Lane

# %% [markdown]
# [TOC](#Table-of-Contents)

# %%
rec = Recorder(0, 150, 0.1)
l = Lane(rec, 2000)
N = 4
DT = 10
DV = 5
for i in range(N):
    v = Vehicle(rec, startingLane=l, t0=i*DT, dx0=10+i*DV)
rec.run()

# %%
rec.plot('t', 'x')

# %%
rec.plot('t', 'x', xmin=20, xmax=70, ymin=0, ymax=600)

# %% [markdown]
# ### Same Scenario on Two Lanes

# %%
N = 4
DT = 10
DV = 5
rec = Recorder(0, 150, 0.1)
l = Lane(rec, 4000)
r = l.widenRight()
for i in range(N):
    v = Vehicle(rec, startingLane=l, t0=i*DT, dx0=10+i*DV)
rec.run()

# %%
rec.plot('t', 'x')

# %% [markdown]
# ### A Larger Number of Vehicles on a Single Lane

# %% [markdown]
# [TOC](#Table-of-Contents)

# %% [markdown]
# When looking at the detail, the brake lights repeatedly beginning at the front and travelling to the end of the queue are noticeable.

# %%
N = 7
DT = 10 # time difference between start
rec = Recorder(0, 300, 0.1)
l = Lane(rec, 5000)
for i in range(N):
    v = Vehicle(rec, startingLane=l, 
                t0=i*DT, dx0=10, t=[15, 30, 50], v=[25+2*i, 25+2*i, 15+2*i])
    v.traceCrash = True
rec.run()

# %%
rec.plot('t', 'x')

# %%
rec.plot('t', 'x', xmin=80, xmax=140, ymin=1500, ymax=2500)

# %% [markdown]
# ### Same Scenario again on two Lanes

# %%
N = 7
DT = 10 # time difference between start
rec = Recorder(0, 300, 0.1)
l = Lane(rec, 5000)
r = l.widenRight()
for i in range(N):
    v = Vehicle(rec, startingLane=l, 
                t0=i*DT, dx0=10, t=[15, 30, 50], v=[25+2*i, 25+2*i, 15+2*i])
    v.traceCrash = True
rec.run()

# %%
rec.plot('t', 'x')

# %% [markdown]
# Note that vehicle v5 is passing v4 on the left side...

# %%
rec.plot('t', 'x', xmin=60, xmax=160, ymin=1000, ymax=4000)

# %% [markdown]
# ## Multiple Vehicles with Fixed Speed Profile (Crash Scenario)

# %% [markdown]
# [TOC](#Table-of-Contents)

# %% [markdown]
# ### Two Vehicles with Not Enough Distance in between

# %%
rec = Recorder(0, 150, 0.1)
l = Lane(rec, 1000)
Vehicle(rec, startingLane=l, t0=0, dx0=10)
Vehicle(rec, startingLane=l, t0=5, dx0=30)
rec.run()

# %%
rec.plot('t', 'x')

# %% [markdown]
# Not enough space for overtaking...

# %%
rec = Recorder(0, 150, 0.1)
l = Lane(rec, 1000)
r = l.widenRight()
Vehicle(rec, startingLane=l, t0=0, dx0=10)
Vehicle(rec, startingLane=l, t0=5, dx0=30)
rec.run()

# %%
rec.plot('t', 'x')

# %% [markdown]
# ### Multiple Vehicles with Not Enough Distance in between¶

# %%
rec = Recorder(0, 150, 0.1)
l = Lane(rec, 1500)
v = Vehicle(rec, startingLane=l, t0=0, dx0=10)
v = Vehicle(rec, startingLane=l, t0=6, dx0=18)
v = Vehicle(rec, startingLane=l, t0=15, dx0=40)
v = Vehicle(rec, startingLane=l, t0=25, dx0=16)
rec.run()

# %%
rec.plot('t', 'x')

# %%
rec.plot('t', 'x', xmin=0, xmax=40, ymin=0, ymax=500)

# %%
rec = Recorder(0, 150, 0.1)
l = Lane(rec, 1500)
r = l.widenRight()
v = Vehicle(rec, startingLane=l, t0=0, dx0=10)
v = Vehicle(rec, startingLane=l, t0=6, dx0=18)
v = Vehicle(rec, startingLane=l, t0=15, dx0=40)
v = Vehicle(rec, startingLane=l, t0=25, dx0=16)
rec.run()

# %%
rec.plot('t', 'x')

# %% [markdown]
# ## Row of Vehicles with Varying Speed

# %% [markdown]
# [TOC](#Table-of-Contents)

# %%
VMAX = 120/3.6
N = 5 # number of points
DT = 5 # time difference between start
rec = Recorder(0, 1000, 1)
l = Lane(rec, 35000)
r = l.widenRight()
for i in range(N):
    v = Vehicle(rec, startingLane=l, t0=i*DT, dx0=VMAX, vmax=VMAX)
    v.traceInterrupt = True
rec.run()

# %%
rec.plot('t', 'x')

# %% [markdown]
# Lets zoom in to magnify the varying distances:

# %%
rec.plot('t', 'x', xmin=600, xmax=650, ymin=19000, ymax=21000)

# %%
rec.plot('t', 'v', xmin=620, xmax=630, ymin=32, ymax=34)

# %% [markdown]
# Let's zoom in to the first braking event: the red point was approaching the green one too fast. Short sharp emergency breaking

# %%
rec.plot('t', 'a', xmin=400, xmax=500)

# %%
rec.plot('x', 'v')

# %%
rec.plot('x', 'a')

# %% [markdown]
# ## Speed Limit

# %% [markdown]
# [TOC](#Table-of-Contents)

# %%
VMAX = 120/3.6
N = 50 # number of points 
IAT = 10 # average interarrival time
random.seed(13)
rec = Recorder(0,600, 1)
iat = [ rv(IAT, delta=0.4*IAT) for i in range(N) ]

l = Lane(rec, 1000)
l.extend(Lane(rec, 1000, speedLimit=80))
l.extend(Lane(rec, 1000))
r = l.widenRight()

t = 0
for i in range(N):
    t += iat[i]
    v = Vehicle(rec, startingLane=l, t0=t, dx0=VMAX, vmax=VMAX, vmax_var=0.01)
rec.run()

# %%
rec.plot('t', 'x', style='b', lw=0.6, decoration=False)

# %% [markdown]
# This demonstrates a stationary traffic condition (speed limit) in a lange segment.

# %%
rec.plot('t', 'x', style='b', lw=0.6, decoration=False,
          y0=1000, y1=2000, fillColor='#ffdddd', xmin=100, xmax=500)

# %% [markdown]
# ## Motorway On-Ramp

# %% [markdown]
# [TOC](#Table-of-Contents)

# %% [markdown]
# ### A Single Vehicle Merging onto an Empty Motorway

# %%
rec = Recorder(0, 200, 1)

l = Lane(rec, 700)
l1 = Lane(rec, 300)
l.extend(l1)
l.extend(Lane(rec, 1000))
r = l.widenRight()

onRamp = Lane(rec, 700)
mergeLane = Lane(rec, 300, merge='R')
onRamp.extend(mergeLane)

l1.attachLeft(mergeLane)
l1.left = None  # don't move from the left lane onto the merge lane

v = Vehicle(rec, startingLane=onRamp, dx0=20)
rec.run()
# Out:
# 300.0   -50.0

# %%
rec.plot('t', 'x')

# %%
rec.getEvents()
# Out:
#       t       x     v  a id lane oldLane     pos             event
# 0     0       0     0  0  0    0      -1     700         lane info
# 1     0       0     0  0  0    1      -1     300         lane info
# 2     0       0     0  0  0    2      -1    1000         lane info
# 3     0       0     0  0  0    3      -1     700         lane info
# 4     0       0     0  0  0    4      -1     300         lane info
# 5     0       0     0  0  0    5      -1    1000         lane info
# 6     0       0     0  0  0    6      -1     700         lane info
# 7     0       0     0  0  0    7      -1     300         lane info
# 8     0       0    20  0  0   -1      -1       0             start
# 9     0       0    20  0  0    6      -1       0        enter lane
# 45   35   700.0  20.0  0  0    6      -1   700.0        leave lane
# 46   35   700.0  20.0  0  0    7      -1     0.0        enter lane
# 48   35   700.0  20.0  0  0    7      -1     0.0       change fast
# 49   35   700.0  20.0  0  0    1       7     0.0      enter lane 1
# 52   38   764.5  23.0  1  0    1       7    64.5      leave lane 7
# 53   38   764.5  23.0  0  0    1      -1    64.5  done change fast
# 65   49  1017.5  23.0  0  0    1      -1   317.5        leave lane
# 66   49  1017.5  23.0  0  0    2      -1    17.5        enter lane
# 110  92  2006.5  23.0  0  0    2      -1  1006.5        leave lane
# 111  92  2006.5  23.0  0  0   -1      -1  1006.5               end

# %% [markdown]
# ### Multiple Vehicles Merging onto an Empty Motorway

# %%
VMAX = 120/3.6

# Vehicles on the On-Ramp
Nmerge = 5
IATmerge = 5

rec = Recorder(0, 200, 1)

l = Lane(rec, 700)
l1 = Lane(rec, 300)
l.extend(l1)
l.extend(Lane(rec, 1000))
r = l.widenRight()

onRamp = Lane(rec, 700)
mergeLane = Lane(rec, 300, merge='R')
onRamp.extend(mergeLane)

l1.attachLeft(mergeLane)
l1.left = None  # don't move from the Motorway onto the on-ramp/merge lane

t = 0
for i in range(Nmerge):
    t += rv(IATmerge, delta=0.4*IATmerge)
    v = Vehicle(rec, startingLane=onRamp, t0=t, dx0=25, vmax=VMAX)
    v.traceOvertaking = True
    v.traceCrash = True

rec.run()
# Out:
# 296.07000000000005   -92.38398743599127
# 281.42999999999995   -95.95297430024125
# 291.27   -96.90008044674407
# 295.98   -92.84032982911879
# 289.30999999999995   -89.3518761852774

# %%
rec.plot('t', 'x')

# %%
rec.getEvents().head(30)
# Out:
#              t       x          v         a id lane oldLane     pos  \
# 0            0       0          0         0  0    0      -1     700
# 1            0       0          0         0  0    1      -1     300
# 2            0       0          0         0  0    2      -1    1000
# 3            0       0          0         0  0    3      -1     700
# 4            0       0          0         0  0    4      -1     300
# 5            0       0          0         0  0    5      -1    1000
# 6            0       0          0         0  0    6      -1     700
# 7            0       0          0         0  0    7      -1     300
# 8     4.834843       0         25         0  0   -1      -1       0
# 9     4.834843       0         25         0  0    6      -1       0
# 14    8.525109       0         25         0  1   -1      -1       0
# 15    8.525109       0         25         0  1    6      -1       0
# 26   13.963937       0         25         0  2   -1      -1       0
# 27   13.963937       0         25         0  2    6      -1       0
# 43   18.849246       0         25         0  3   -1      -1       0
# 44   18.849246       0         25         0  3    6      -1       0
# 69   24.347468       0         25         0  4   -1      -1       0
# 70   24.347468       0         25         0  4    6      -1       0
# 106         32  703.93  27.185877  0.097911  0    6      -1  703.93
# 107         32  703.93  27.185877  0.097911  0    7      -1    3.93
# 113         32  703.93  27.185877  0.097911  0    7      -1    3.93
# 114         32  703.93  27.185877  0.097911  0    1       7    3.93
# 125         35   790.0  30.185877         1  0    1       7    90.0
# 126         35   790.0  30.185877         0  0    1      -1    90.0
# 133         36  718.57  27.706025  0.116891  1    6      -1  718.57
# 134         36  718.57  27.706025  0.116891  1    7      -1   18.57
# 139         36  718.57  27.706025  0.116891  1    7      -1   18.57
# 140         36  718.57  27.706025  0.116891  1    1       7   18.57
# 151         39   806.2  30.706025         1  1    1       7   106.2
# 152         39   806.2  30.706025         0  1    1      -1   106.2
#
#                 event
# 0           lane info
# 1           lane info
# 2           lane info
# 3           lane info
# 4           lane info
# 5           lane info
# 6           lane info
# 7           lane info
# 8               start
# 9          enter lane
# 14              start
# 15         enter lane
# 26              start
# 27         enter lane
# 43              start
# 44         enter lane
# 69              start
# 70         enter lane
# 106        leave lane
# 107        enter lane
# 113       change fast
# 114      enter lane 1
# 125      leave lane 7
# 126  done change fast
# 133        leave lane
# 134        enter lane
# 139       change fast
# 140      enter lane 1
# 151      leave lane 7
# 152  done change fast

# %% [markdown]
# ### A Single Vehicle Merging onto a busy Motorway

# %%
N = 10
IAT = 5
VMAX = 120/3.6

rec = Recorder(0, 200, 1)

l = Lane(rec, 700)
l1 = Lane(rec, 300)
l.extend(l1)
l.extend(Lane(rec, 1000))
r = l.widenRight()

onRamp = Lane(rec, 700)
mergeLane = Lane(rec, 300, merge='R')
onRamp.extend(mergeLane)

l1.attachLeft(mergeLane)
l1.left = None  # don't move from the Motorway onto the on-ramp/merge lane

v = Vehicle(rec, startingLane=onRamp, dx0=25, vmax=VMAX)
v.traceOvertaking = True

t = 0
for i in range(N):
    t += rv(IAT, delta=0.4*IAT)
    vmax = VMAX  # random_free_speed()/3.6
    v = Vehicle(rec, startingLane=l, t0=t, dx0=vmax, vmax=vmax)
    v.traceOvertaking = True
    
rec.run()
# Out:
# 299.59000000000003   -93.02672599756278
# 272.26   -93.73836666155879
# 244.82000000000005   -94.45271893651834
# 217.27999999999997   -95.16978282244143
# t=   31.0s x=  748.6m v2 Overtaking v0  at x=  748.6m
# t=   65.0s x=1,687.7m v3 Overtaking v0  at x=1,687.7m
# t=   73.0s x=1,978.4m v3 Overtaking done return to slow lane at x=1,978.4m

# %%
rec.plot('t', 'x')

# %%
rec.getEvents().head(30)
# Out:
#              t       x          v         a id lane oldLane     pos  \
# 0            0       0          0         0  0    0      -1     700
# 1            0       0          0         0  0    1      -1     300
# 2            0       0          0         0  0    2      -1    1000
# 3            0       0          0         0  0    3      -1     700
# 4            0       0          0         0  0    4      -1     300
# 5            0       0          0         0  0    5      -1    1000
# 6            0       0          0         0  0    6      -1     700
# 7            0       0          0         0  0    7      -1     300
# 8            0       0         25         0  0   -1      -1       0
# 9            0       0         25         0  0    6      -1       0
# 15    4.926227       0  33.333333         0  1   -1      -1       0
# 16    4.926227       0  33.333333         0  1    0      -1       0
# 25    8.594902       0  33.333333         0  2   -1      -1       0
# 26    8.594902       0  33.333333         0  2    0      -1       0
# 45   14.371051       0  33.333333         0  3   -1      -1       0
# 46   14.371051       0  33.333333         0  3    0      -1       0
# 63   18.683333       0  33.333333         0  4   -1      -1       0
# 64   18.683333       0  33.333333         0  4    0      -1       0
# 95   24.198302       0  33.333333         0  5   -1      -1       0
# 96   24.198302       0  33.333333         0  5    0      -1       0
# 104         26  702.96    33.3953  0.003933  1    0      -1  702.96
# 105         26  702.96    33.3953  0.003933  1    1      -1    2.96
# 111         27  700.41  27.280282  0.104146  0    6      -1  700.41
# 112         27  700.41  27.280282  0.104146  0    7      -1    0.41
# 131  29.197074       0  33.333333         0  6   -1      -1       0
# 132  29.197074       0  33.333333         0  6    0      -1       0
# 134         30  715.03   33.51987  0.011561  2    0      -1  715.03
# 135         30  715.03   33.51987  0.011561  2    1      -1   15.03
# 142         30  782.72  27.592721  0.104146  0    7      -1   82.72
# 143         30  782.72  27.592721  0.104146  0    1       7   82.72
#
#             event
# 0       lane info
# 1       lane info
# 2       lane info
# 3       lane info
# 4       lane info
# 5       lane info
# 6       lane info
# 7       lane info
# 8           start
# 9      enter lane
# 15          start
# 16     enter lane
# 25          start
# 26     enter lane
# 45          start
# 46     enter lane
# 63          start
# 64     enter lane
# 95          start
# 96     enter lane
# 104    leave lane
# 105    enter lane
# 111    leave lane
# 112    enter lane
# 131         start
# 132    enter lane
# 134    leave lane
# 135    enter lane
# 142   change fast
# 143  enter lane 1

# %% [markdown]
# ### Multiple Vehicles Merging onto a very busy Motorway

# %%
VMAX = 120/3.6

# Vehicles on the Motorway
N = 25
IAT = 4

# Vehicles on the On-Ramp
Nmerge = 15
IATmerge = 8

rec = Recorder(0, 200, 1)

l = Lane(rec, 700)
l1 = Lane(rec, 300)
l.extend(l1)
l.extend(Lane(rec, 1000))
r = l.widenRight()

onRamp = Lane(rec, 700)
mergeLane = Lane(rec, 300, merge='R')
onRamp.extend(mergeLane)

l1.attachLeft(mergeLane)
l1.left = None  # don't move from the Motorway onto the on-ramp/merge lane

t = 0
for i in range(Nmerge):
    t += rv(IATmerge, delta=0.4*IATmerge)
    v = Vehicle(rec, startingLane=onRamp, t0=t, dx0=vmax, vmax=VMAX)
    v.traceOvertaking = True
    v.traceCrash = True

t = 0
for i in range(N):
    t += rv(IAT, delta=0.4*IAT)
    vmax = VMAX  # random_free_speed()/3.6
    v = Vehicle(rec, startingLane=l, t0=t, dx0=vmax, vmax=VMAX)
    v.traceOvertaking = True
    v.traceCrash = True
    
rec.run()
# Out:
# speeding back up
# speeding back up
# speeding back up
# speeding back up
# speeding back up
# speeding back up
# t=   43.0s x=  870.9m v1 Overtaking v17  at x=  870.9m
# speeding back up
# t=   49.0s x=  845.0m v2 Overtaking v19  at x=  845.0m
# t=   57.0s x=  735.6m v22 Overtaking v3  at x=  735.6m
# speeding back up
# t=   65.0s x=  841.2m v4 Overtaking v23  at x=  841.2m
# t=   70.0s x=1,028.9m v23 Overtaking v3  at x=1,028.9m
# t=   72.0s x=  629.7m v26 Overtaking v5  at x=  629.7m
# speeding back up
# speeding back up
# t=   80.0s x=  766.3m v27 Overtaking v6  at x=  766.3m
# t=   83.0s x=  751.6m v28 Overtaking v6  at x=  751.6m
# speeding back up
# t=   88.0s x=  752.0m v29 Overtaking v7  at x=  752.0m
# t=   90.0s x=1,131.1m v27 Overtaking done return to slow lane at x=1,131.1m
# t=   91.0s x=  725.9m v30 Overtaking v7  at x=  725.9m
# speeding back up
# t=   97.0s x=1,998.5m v23 Crashed into v4 at x= 1998.5m
# t=   97.0s x=  645.4m v32 Overtaking v31  at x=  645.4m
# t=   98.7s x=  835.4m v31 Overtaking v8  at x=  835.4m
# t=  104.0s x=  755.2m v33 Overtaking v9  at x=  755.2m
# speeding back up
# t=  109.0s x=1,864.8m v27 Overtaking v5  at x=1,864.8m
# t=  112.0s x=  738.2m v35 Overtaking v10  at x=  738.2m
# t=  113.0s x=  892.6m v34 Overtaking v9  at x=  892.6m
# speeding back up
# t=  116.0s x=  755.0m v36 Overtaking v10  at x=  755.0m
# t=  120.0s x=  754.8m v37 Overtaking v11  at x=  754.8m
# speeding back up
# t=  122.0s x=1,995.2m v28 Crashed into v23 at x= 1995.2m
# t=  122.0s x=1,823.0m v7 Overtaking v6  at x=1,823.0m
# t=  123.0s x=  740.3m v38 Overtaking v11  at x=  740.3m
# t=  124.0s x=1,993.8m v29 Crashed into v28 at x= 1993.8m
# t=  129.0s x=1,355.7m v35 Overtaking done return to slow lane at x=1,355.7m
# t=  129.9s x=  809.7m v39 Overtaking v12  at x=  809.7m
# t=  131.0s x=1,155.3m v37 Overtaking done return to slow lane at x=1,155.3m
# t=  137.0s x=1,991.2m v31 Crashed into v29 at x= 1991.2m
# t=  138.0s x=1,997.3m v32 Crashed into v23 at x= 1997.3m
# t=  165.1s x=1,983.9m v38 Overtaking done return to slow lane at x=1,983.9m

# %%
rec.plot('t', 'x')

# %%
rec.plot('t','x', ymax = 1200, ymin = 0, xmin =30, xmax = 110)

# %%
rec.getEvents().head(30)
# Out:
#              t       x          v        a  id lane oldLane     pos  \
# 0            0       0          0        0   0    0      -1     700
# 1            0       0          0        0   0    1      -1     300
# 2            0       0          0        0   0    2      -1    1000
# 3            0       0          0        0   0    3      -1     700
# 4            0       0          0        0   0    4      -1     300
# 5            0       0          0        0   0    5      -1    1000
# 6            0       0          0        0   0    6      -1     700
# 7            0       0          0        0   0    7      -1     300
# 8       3.9167       0  33.333333        0  10   -1      -1       0
# 9       3.9167       0  33.333333        0  10    0      -1       0
# 14     7.92224       0  33.333333        0   0   -1      -1       0
# 15     7.92224       0  33.333333        0   0    6      -1       0
# 18    8.369052       0  33.333333        0  11   -1      -1       0
# 19    8.369052       0  33.333333        0  11    0      -1       0
# 29   11.579043       0  33.333333        0  12   -1      -1       0
# 30   11.579043       0  33.333333        0  12    0      -1       0
# 47   15.480541       0  33.333333        0  13   -1      -1       0
# 48   15.480541       0  33.333333        0  13    0      -1       0
# 49   15.575749       0  33.333333        0   1   -1      -1       0
# 50   15.575749       0  33.333333        0   1    6      -1       0
# 75   19.000448       0  33.333333        0  14   -1      -1       0
# 76   19.000448       0  33.333333        0  14    0      -1       0
# 98   22.791223       0  33.333333        0   2   -1      -1       0
# 99   22.791223       0  33.333333        0   2    6      -1       0
# 108  23.299163       0  33.333333        0  15   -1      -1       0
# 109  23.299163       0  33.333333        0  15    0      -1       0
# 119         25  702.96  33.357549  0.00143  10    0      -1  702.96
# 120         25  702.96  33.357549  0.00143  10    1      -1    2.96
# 148  27.889497       0  33.333333        0  16   -1      -1       0
# 149  27.889497       0  33.333333        0  16    0      -1       0
#
#           event
# 0     lane info
# 1     lane info
# 2     lane info
# 3     lane info
# 4     lane info
# 5     lane info
# 6     lane info
# 7     lane info
# 8         start
# 9    enter lane
# 14        start
# 15   enter lane
# 18        start
# 19   enter lane
# 29        start
# 30   enter lane
# 47        start
# 48   enter lane
# 49        start
# 50   enter lane
# 75        start
# 76   enter lane
# 98        start
# 99   enter lane
# 108       start
# 109  enter lane
# 119  leave lane
# 120  enter lane
# 148       start
# 149  enter lane

# %% [markdown]
# ## Row of Vehicles with Varying Speed and Interarrival Times

# %% [markdown]
# [TOC](#Table-of-Contents)

# %%
VMAX = 120/3.6
N = 10 # number of vehicles
IAT = 1 # average interarrival time
random.seed(13)
rec = Recorder(0, 500, 1)
iat = [ rv(IAT, delta=0.4*IAT) for i in range(N) ]

l = Lane(rec, 1000)
while l.totalLength()<4000:
    l.extend(Lane(rec, 1000))
r = l.widenRight()

t = 0
for i in range(N):
    t += iat[i]
    v = Vehicle(rec, startingLane=l if i%2==0 else r, t0=t, dx0=VMAX, vmax=VMAX)
    v.traceCrash = True
rec.run()

# %%
rec.plot('t', 'x')

# %% [markdown]
# Zooming in...

# %%
rec.plot('t', 'x', xmin=50, xmax=100, ymin=0, ymax=1000, style='b', lw=0.6)

# %% [markdown]
# This plot shows horizontally a **flow** of about 10 veh per 10 secs (3600 veh/h), and vertically a **density** of about 30 veh/km, measured across two lanes. This means an average (gross) space of 66.6m between vehicles in a lane, which is about the recomended safety distance at a speed of 120km/h.
#
# Again **density** × **speed** = **flow**: `30 [veh/km]` × `120 [km/h]` = `3600 [veh/h]`

# %%
rec.plot('t', 'v', xmin=50, xmax=100)

# %% [markdown]
# ## Row of Vehicles with Varying Max Speed, Speed and Interarrival Times

# %% [markdown]
# [TOC](#Table-of-Contents)

# %%
N = 10 # number of points 
IAT = 2 # average interarrival time
random.seed(13)
rec = Recorder(0, 500, 1)
iat = [ rv(IAT, delta=0.4*IAT) for i in range(N) ]

l = Lane(rec, 1000)
while l.totalLength()<4000:
    l.extend(Lane(rec, 1000))
r = l.widenRight()

t = 0
for i in range(N):
    t += iat[i]
    v = Vehicle(rec, startingLane=l, t0=t, dx0=80/3.6, vmax=random_free_speed()/3.6)
    v.traceCrash = True
rec.run()

# %%
rec.plot('t', 'x')

# %%
rec.plot('t', 'x', xmin=50, xmax=100, ymin=0, ymax=2000, lw=0.6)
